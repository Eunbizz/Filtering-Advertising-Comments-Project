# %%
# past_data= pd.read_csv('/content/drive/MyDrive/비타민_자율프로젝트/data3.csv')
# past_data
# Out:
#        label                                               text
# 0          1  제주여행의 일정 중 한 곳이던 서귀포 올레시장 먹거리로 아침 겸 점심을 누리고 왔어...
# 1          1  허기를 채우려고 감자 샐러드를 먹어보니 보드랍고 꼬숩한 맛이 너무 좋았어요 기본 찬...
# 2          1  연이어 앞에 고등어 구이는 이날 간만에 즐겨봤어요 그냥 봤을 때는 평범한 비주얼인데...
# 3          1  친구도 밥에 얹어서 가득 맛보더니 맛있다며 감탄하더라고요 살코기만 먹어도 너무 맛있...
# 4          1  밑반찬에 나오는 미역국도 미역도 알차고 삼삼하며 개운하니 떠먹기 좋았어요 저는 한 ...
# ...      ...                                                ...
# 20942      0  미사리 조정경기장 핑크뮬리만개했어요 3인용 자전거 존 잼미사리 조정경기장 미사리 하...
# 20943      0  동편마을 카페인데 음료당 귀여운 선인장을 줘 요귀여워서 기분 좋아짐 동편마을 카페인...
# 20944      0                      멍레터 받은 덜덜 이에 요 너무 귀엽 다수정됨 64주
# 20945      0  87구 공탄 연탄불 고기 남친 돈남친산파 불고기 양보이시나 요저만큼에 8천원이라니 ...
# 20946      0  브런치 연남동 마나올라나 카프레제샌드위치 프렌치 토스트마나 올라나 연남동 마나올라나...
#
# [20947 rows x 2 columns]

# %%
# new_data = pd.read_csv('/content/drive/MyDrive/비타민_자율프로젝트/data6.csv')

# new_data
# Out:
#        Unnamed: 0                                               text  label
# 0               0        얼마 전에 연말을 맞이하여 새마음으로\n성신여대 미용실 모노라인에 다녀왔어요.      1
# 1               1  이번에 제가 방문했었던\n지나인헤어 본점이에요.\n참고로 위치는 보문역 5분출구로 ...      1
# 2               2  이번에 다녀온 곳은\n무트나인헤어!!\n성신여대입구역 1번 출구로 나와서\n공차 골...      1
# 3               3                      바로 헤어 더뷰입니다\n매장은 2층에 위치해 있습니다      1
# 4               4  요새 일이 너무 바빠서 미용실을\n못 간 지 꽤 오래되었더라고요.\n그래서 근처에 ...      1
# ...           ...                                                ...    ...
# 10522       10522  우와~~~~~ 우리 길듕이 원래 멋있었지만\n펌 하고 나니 멋짐이 UP! UP!\n...      0
# 10523       10523        길듕이도 딱 원하는 자연스러움, 컬링이라며\n만족, 만족 대~~만족을 하네요.      0
# 10524       10524  말해 모해! 김해미용실추천, 김해미용실 찾는다면\n던뮤어 헤어에서 도경 실장님을 찾...      0
# 10525       10525                                 "지저분녀"에서 "깔끔녀"로 ??      0
# 10526       10526  (증거사진 첨부합니다)\n전 12월에 클리닉 받으러 또 방문예정이구요,,\n앞으론 ...      0
#
# [10527 rows x 3 columns]

# %%
# data = pd.concat([past_data,new_data])
# data.reset_index(inplace=True)

# data = data[['text','label']]
# data
# Out:
#                                                     text  label
# 0      제주여행의 일정 중 한 곳이던 서귀포 올레시장 먹거리로 아침 겸 점심을 누리고 왔어...      1
# 1      허기를 채우려고 감자 샐러드를 먹어보니 보드랍고 꼬숩한 맛이 너무 좋았어요 기본 찬...      1
# 2      연이어 앞에 고등어 구이는 이날 간만에 즐겨봤어요 그냥 봤을 때는 평범한 비주얼인데...      1
# 3      친구도 밥에 얹어서 가득 맛보더니 맛있다며 감탄하더라고요 살코기만 먹어도 너무 맛있...      1
# 4      밑반찬에 나오는 미역국도 미역도 알차고 삼삼하며 개운하니 떠먹기 좋았어요 저는 한 ...      1
# ...                                                  ...    ...
# 31469  우와~~~~~ 우리 길듕이 원래 멋있었지만\n펌 하고 나니 멋짐이 UP! UP!\n...      0
# 31470        길듕이도 딱 원하는 자연스러움, 컬링이라며\n만족, 만족 대~~만족을 하네요.      0
# 31471  말해 모해! 김해미용실추천, 김해미용실 찾는다면\n던뮤어 헤어에서 도경 실장님을 찾...      0
# 31472                                 "지저분녀"에서 "깔끔녀"로 ??      0
# 31473  (증거사진 첨부합니다)\n전 12월에 클리닉 받으러 또 방문예정이구요,,\n앞으론 ...      0
#
# [31474 rows x 2 columns]

# %% [markdown]
# #### 필요한 패키지 호출

# %%
# Colab에 Mecab 설치
# !git clone https://github.com/SOMJANG/Mecab-ko-for-Google-Colab.git
# %cd Mecab-ko-for-Google-Colab
# !bash install_mecab-ko_on_colab190912.sh

# 필요한 모듈 불러오기

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import urllib.request
from collections import Counter
from konlpy.tag import Mecab
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

import re
from tensorflow.keras.layers import Embedding, Dense, LSTM, Bidirectional
from tensorflow.keras.models import Sequential
from tensorflow.keras.models import load_model
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
# Out:
# Cloning into 'Mecab-ko-for-Google-Colab'...
# remote: Enumerating objects: 115, done.
# remote: Counting objects: 100% (24/24), done.
# remote: Compressing objects: 100% (20/20), done.
# remote: Total 115 (delta 11), reused 10 (delta 3), pack-reused 91
# Receiving objects: 100% (115/115), 1.27 MiB | 2.16 MiB/s, done.
# Resolving deltas: 100% (50/50), done.
# /content/Mecab-ko-for-Google-Colab
# Installing konlpy.....
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.4/19.4 MB 41.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 465.6/465.6 KB 28.3 MB/s eta 0:00:00
# ...
# Done
# Installing mecab-0.996-ko-0.9.2.tar.gz.....
# ...
# from https://bitbucket.org/eunjeon/mecab-ko/downloads/mecab-0.996-ko-0.9.2.tar.gz
# --2023-02-01 06:12:05--  https://bitbucket.org/eunjeon/mecab-ko/downloads/mecab-0.996-ko-0.9.2.tar.gz
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# #### 미용실 데이터 결합

# %%
import pandas as pd
hair_ad_data= pd.read_csv('/content/drive/MyDrive/비타민_자율프로젝트/hear_ad_data_6000.csv')
hair_ad_data.drop(columns=['Unnamed: 1','Unnamed: 2'],inplace=True)
hair_ad_data = hair_ad_data.dropna(axis=0)
#hair_ad_data.reset_index(inplace=True)
hair_ad_data
# Out:
#                                                    text
# 0           얼마 전에 연말을 맞이하여 새마음으로\n성신여대 미용실 모노라인에 다녀왔어요.
# 1     이번에 제가 방문했었던\n지나인헤어 본점이에요.\n참고로 위치는 보문역 5분출구로 ...
# 2     이번에 다녀온 곳은\n무트나인헤어!!\n성신여대입구역 1번 출구로 나와서\n공차 골...
# 3                         바로 헤어 더뷰입니다\n매장은 2층에 위치해 있습니다
# 4     요새 일이 너무 바빠서 미용실을\n못 간 지 꽤 오래되었더라고요.\n그래서 근처에 ...
# ...                                                 ...
# 7071  + #내돈내산 후기\n#동탄미용실 #반송동미용실 #준오헤어 #준오헤어동탄타임테라스점...
# 7072  방배 미용실은 샴푸실도\n엄청 예쁘게 꾸며져 있더라구요.\n다른 미용실들과는 달리\...
# 7077            주소\n서울 영등포구 영중로 18\n연락처\n0507-1493-0608
# 7084                                 준오헤어 포스코사거리점 위치에요!
# 7088  마포미용실 남자머리 하러 온 준오헤어 합정메세나폴리스점은 합정역 9번출구에서 이어지...
#
# [5491 rows x 1 columns]

# %%
hair_ad_data['label'] = 1
hair_ad_data
# Out:
#                                                    text  label
# 0           얼마 전에 연말을 맞이하여 새마음으로\n성신여대 미용실 모노라인에 다녀왔어요.      1
# 1     이번에 제가 방문했었던\n지나인헤어 본점이에요.\n참고로 위치는 보문역 5분출구로 ...      1
# 2     이번에 다녀온 곳은\n무트나인헤어!!\n성신여대입구역 1번 출구로 나와서\n공차 골...      1
# 3                         바로 헤어 더뷰입니다\n매장은 2층에 위치해 있습니다      1
# 4     요새 일이 너무 바빠서 미용실을\n못 간 지 꽤 오래되었더라고요.\n그래서 근처에 ...      1
# ...                                                 ...    ...
# 7071  + #내돈내산 후기\n#동탄미용실 #반송동미용실 #준오헤어 #준오헤어동탄타임테라스점...      1
# 7072  방배 미용실은 샴푸실도\n엄청 예쁘게 꾸며져 있더라구요.\n다른 미용실들과는 달리\...      1
# 7077            주소\n서울 영등포구 영중로 18\n연락처\n0507-1493-0608      1
# 7084                                 준오헤어 포스코사거리점 위치에요!      1
# 7088  마포미용실 남자머리 하러 온 준오헤어 합정메세나폴리스점은 합정역 9번출구에서 이어지...      1
#
# [5491 rows x 2 columns]

# %%
hair_non_data = pd.read_csv('/content/drive/MyDrive/비타민_자율프로젝트/미용실데이터최종.csv')


hair_non_data = hair_non_data.dropna(axis=0)
# # hair_non_data.reset_index(inplace=True)
hair_non_data
# Out:
#                                                    text  label
# 0     솔리체헤어\n055-337-2797\n경남 김해시 경원로73번길 15\n경보더숨시티...      0
# 1     이정도 길이였는데, 이때 머리 예쁘게 잘라주셔서\n엄청 좋았더라는\n이때 머리 마음...      0
# 2                           나의 최애\n#증평미용실추천\n#증평미용실내돈내산      0
# 3     미사역에서 완전 가까워요!!\n전 항상 차량을 가져가는데\n주차도 무료이고,\n자리...      0
# 4     고잔동 aw컨벤션근처에있는\n고잔동헤어썸~~\n여기는 예약필수!!\n인기가 많은 미...      0
# ...                                                 ...    ...
# 8984  우와~~~~~ 우리 길듕이 원래 멋있었지만\n펌 하고 나니 멋짐이 UP! UP!\n...      0
# 8985        길듕이도 딱 원하는 자연스러움, 컬링이라며\n만족, 만족 대~~만족을 하네요.      0
# 8986  말해 모해! 김해미용실추천, 김해미용실 찾는다면\n던뮤어 헤어에서 도경 실장님을 찾...      0
# 8987                                 "지저분녀"에서 "깔끔녀"로 ??      0
# 8988  (증거사진 첨부합니다)\n전 12월에 클리닉 받으러 또 방문예정이구요,,\n앞으론 ...      0
#
# [8989 rows x 2 columns]

# %%
data = pd.concat([hair_ad_data,hair_non_data])
#data.drop_duplicates(subset=None, keep='first', inplace=False, ignore_index=False)

#data = data.reset_index( drop=False, inplace=False)
data
# Out:
#                                                    text  label
# 0           얼마 전에 연말을 맞이하여 새마음으로\n성신여대 미용실 모노라인에 다녀왔어요.      1
# 1     이번에 제가 방문했었던\n지나인헤어 본점이에요.\n참고로 위치는 보문역 5분출구로 ...      1
# 2     이번에 다녀온 곳은\n무트나인헤어!!\n성신여대입구역 1번 출구로 나와서\n공차 골...      1
# 3                         바로 헤어 더뷰입니다\n매장은 2층에 위치해 있습니다      1
# 4     요새 일이 너무 바빠서 미용실을\n못 간 지 꽤 오래되었더라고요.\n그래서 근처에 ...      1
# ...                                                 ...    ...
# 5207        길듕이도 딱 원하는 자연스러움, 컬링이라며\n만족, 만족 대~~만족을 하네요.      0
# 5208  개인적으로 아윤채는 꽤 만족스러운 제품이기에\n써보시는 것도 괜찮을 거 같아요.\n...      0
# 5236  말해 모해! 김해미용실추천, 김해미용실 찾는다면\n던뮤어 헤어에서 도경 실장님을 찾...      0
# 5305                                 "지저분녀"에서 "깔끔녀"로 ??      0
# 5344  (증거사진 첨부합니다)\n전 12월에 클리닉 받으러 또 방문예정이구요,,\n앞으론 ...      0
#
# [6604 rows x 2 columns]

# %%
data = data.drop_duplicates(subset=None, keep='first', inplace=False, ignore_index=False)
data
# Out:
#                                                    text  label
# 0           얼마 전에 연말을 맞이하여 새마음으로\n성신여대 미용실 모노라인에 다녀왔어요.      1
# 1     이번에 제가 방문했었던\n지나인헤어 본점이에요.\n참고로 위치는 보문역 5분출구로 ...      1
# 2     이번에 다녀온 곳은\n무트나인헤어!!\n성신여대입구역 1번 출구로 나와서\n공차 골...      1
# 3                         바로 헤어 더뷰입니다\n매장은 2층에 위치해 있습니다      1
# 4     요새 일이 너무 바빠서 미용실을\n못 간 지 꽤 오래되었더라고요.\n그래서 근처에 ...      1
# ...                                                 ...    ...
# 6597  우와~~~~~ 우리 길듕이 원래 멋있었지만\n펌 하고 나니 멋짐이 UP! UP!\n...      0
# 6599        길듕이도 딱 원하는 자연스러움, 컬링이라며\n만족, 만족 대~~만족을 하네요.      0
# 6601  말해 모해! 김해미용실추천, 김해미용실 찾는다면\n던뮤어 헤어에서 도경 실장님을 찾...      0
# 6602                                 "지저분녀"에서 "깔끔녀"로 ??      0
# 6603  (증거사진 첨부합니다)\n전 12월에 클리닉 받으러 또 방문예정이구요,,\n앞으론 ...      0
#
# [6279 rows x 2 columns]

# %%
data = data.reset_index(drop=True)
data
# Out:
#                                                    text  label
# 0           얼마 전에 연말을 맞이하여 새마음으로\n성신여대 미용실 모노라인에 다녀왔어요.      1
# 1     이번에 제가 방문했었던\n지나인헤어 본점이에요.\n참고로 위치는 보문역 5분출구로 ...      1
# 2     이번에 다녀온 곳은\n무트나인헤어!!\n성신여대입구역 1번 출구로 나와서\n공차 골...      1
# 3                         바로 헤어 더뷰입니다\n매장은 2층에 위치해 있습니다      1
# 4     요새 일이 너무 바빠서 미용실을\n못 간 지 꽤 오래되었더라고요.\n그래서 근처에 ...      1
# ...                                                 ...    ...
# 6274  우와~~~~~ 우리 길듕이 원래 멋있었지만\n펌 하고 나니 멋짐이 UP! UP!\n...      0
# 6275        길듕이도 딱 원하는 자연스러움, 컬링이라며\n만족, 만족 대~~만족을 하네요.      0
# 6276  말해 모해! 김해미용실추천, 김해미용실 찾는다면\n던뮤어 헤어에서 도경 실장님을 찾...      0
# 6277                                 "지저분녀"에서 "깔끔녀"로 ??      0
# 6278  (증거사진 첨부합니다)\n전 12월에 클리닉 받으러 또 방문예정이구요,,\n앞으론 ...      0
#
# [6279 rows x 2 columns]

# %%
# 라벨 합친 최종
data2 = pd.read_csv('/content/drive/MyDrive/비타민_자율프로젝트/미용실데이터최종.csv')
data2
# Out:
#                                                    text  label
# 0     솔리체헤어\n055-337-2797\n경남 김해시 경원로73번길 15\n경보더숨시티...      0
# 1     이정도 길이였는데, 이때 머리 예쁘게 잘라주셔서\n엄청 좋았더라는\n이때 머리 마음...      0
# 2                           나의 최애\n#증평미용실추천\n#증평미용실내돈내산      0
# 3     미사역에서 완전 가까워요!!\n전 항상 차량을 가져가는데\n주차도 무료이고,\n자리...      0
# 4     고잔동 aw컨벤션근처에있는\n고잔동헤어썸~~\n여기는 예약필수!!\n인기가 많은 미...      0
# ...                                                 ...    ...
# 8984  우와~~~~~ 우리 길듕이 원래 멋있었지만\n펌 하고 나니 멋짐이 UP! UP!\n...      0
# 8985        길듕이도 딱 원하는 자연스러움, 컬링이라며\n만족, 만족 대~~만족을 하네요.      0
# 8986  말해 모해! 김해미용실추천, 김해미용실 찾는다면\n던뮤어 헤어에서 도경 실장님을 찾...      0
# 8987                                 "지저분녀"에서 "깔끔녀"로 ??      0
# 8988  (증거사진 첨부합니다)\n전 12월에 클리닉 받으러 또 방문예정이구요,,\n앞으론 ...      0
#
# [8989 rows x 2 columns]

# %%
data_all = pd.concat([hair_ad_data,data2])
data_all
# Out:
#                                                    text  label
# 0           얼마 전에 연말을 맞이하여 새마음으로\n성신여대 미용실 모노라인에 다녀왔어요.      1
# 1     이번에 제가 방문했었던\n지나인헤어 본점이에요.\n참고로 위치는 보문역 5분출구로 ...      1
# 2     이번에 다녀온 곳은\n무트나인헤어!!\n성신여대입구역 1번 출구로 나와서\n공차 골...      1
# 3                         바로 헤어 더뷰입니다\n매장은 2층에 위치해 있습니다      1
# 4     요새 일이 너무 바빠서 미용실을\n못 간 지 꽤 오래되었더라고요.\n그래서 근처에 ...      1
# ...                                                 ...    ...
# 8984  우와~~~~~ 우리 길듕이 원래 멋있었지만\n펌 하고 나니 멋짐이 UP! UP!\n...      0
# 8985        길듕이도 딱 원하는 자연스러움, 컬링이라며\n만족, 만족 대~~만족을 하네요.      0
# 8986  말해 모해! 김해미용실추천, 김해미용실 찾는다면\n던뮤어 헤어에서 도경 실장님을 찾...      0
# 8987                                 "지저분녀"에서 "깔끔녀"로 ??      0
# 8988  (증거사진 첨부합니다)\n전 12월에 클리닉 받으러 또 방문예정이구요,,\n앞으론 ...      0
#
# [14480 rows x 2 columns]

# %%
data_all = data_all.drop_duplicates(subset=None, keep='first', inplace=False, ignore_index=False)
data_all
# Out:
#                                                    text  label
# 0           얼마 전에 연말을 맞이하여 새마음으로\n성신여대 미용실 모노라인에 다녀왔어요.      1
# 1     이번에 제가 방문했었던\n지나인헤어 본점이에요.\n참고로 위치는 보문역 5분출구로 ...      1
# 2     이번에 다녀온 곳은\n무트나인헤어!!\n성신여대입구역 1번 출구로 나와서\n공차 골...      1
# 3                         바로 헤어 더뷰입니다\n매장은 2층에 위치해 있습니다      1
# 4     요새 일이 너무 바빠서 미용실을\n못 간 지 꽤 오래되었더라고요.\n그래서 근처에 ...      1
# ...                                                 ...    ...
# 8984  우와~~~~~ 우리 길듕이 원래 멋있었지만\n펌 하고 나니 멋짐이 UP! UP!\n...      0
# 8985        길듕이도 딱 원하는 자연스러움, 컬링이라며\n만족, 만족 대~~만족을 하네요.      0
# 8986  말해 모해! 김해미용실추천, 김해미용실 찾는다면\n던뮤어 헤어에서 도경 실장님을 찾...      0
# 8987                                 "지저분녀"에서 "깔끔녀"로 ??      0
# 8988  (증거사진 첨부합니다)\n전 12월에 클리닉 받으러 또 방문예정이구요,,\n앞으론 ...      0
#
# [10527 rows x 2 columns]

# %%
data = data_all.reset_index(drop=True)
data
# Out:
#                                                     text  label
# 0            얼마 전에 연말을 맞이하여 새마음으로\n성신여대 미용실 모노라인에 다녀왔어요.      1
# 1      이번에 제가 방문했었던\n지나인헤어 본점이에요.\n참고로 위치는 보문역 5분출구로 ...      1
# 2      이번에 다녀온 곳은\n무트나인헤어!!\n성신여대입구역 1번 출구로 나와서\n공차 골...      1
# 3                          바로 헤어 더뷰입니다\n매장은 2층에 위치해 있습니다      1
# 4      요새 일이 너무 바빠서 미용실을\n못 간 지 꽤 오래되었더라고요.\n그래서 근처에 ...      1
# ...                                                  ...    ...
# 10522  우와~~~~~ 우리 길듕이 원래 멋있었지만\n펌 하고 나니 멋짐이 UP! UP!\n...      0
# 10523        길듕이도 딱 원하는 자연스러움, 컬링이라며\n만족, 만족 대~~만족을 하네요.      0
# 10524  말해 모해! 김해미용실추천, 김해미용실 찾는다면\n던뮤어 헤어에서 도경 실장님을 찾...      0
# 10525                                 "지저분녀"에서 "깔끔녀"로 ??      0
# 10526  (증거사진 첨부합니다)\n전 12월에 클리닉 받으러 또 방문예정이구요,,\n앞으론 ...      0
#
# [10527 rows x 2 columns]

# %%
data.to_csv("/content/drive/MyDrive/비타민_자율프로젝트/data6.csv")

# %%
data
# Out:
#        Unnamed: 0                                               text  label  \
# 0               0           얼마 전에 연말을 맞이하여 새마음으로성신여대 미용실 모노라인에 다녀왔어요      1
# 1               1  이번에 제가 방문했었던지나인헤어 본점이에요참고로 위치는 보문역 분출구로 나와길을 따...      1
# 2               2  이번에 다녀온 곳은무트나인헤어성신여대입구역 번 출구로 나와서공차 골목으로 꺾은 다음...      1
# 3               3                         바로 헤어 더뷰입니다매장은 층에 위치해 있습니다      1
# 4               4  요새 일이 너무 바빠서 미용실을못 간 지 꽤 오래되었더라고요그래서 근처에 괜찮은성신...      1
# ...           ...                                                ...    ...
# 10522       10522  우와 우리 길듕이 원래 멋있었지만펌 하고 나니 멋짐이  길듕이 보다 제가 더 만족스...      0
# 10523       10523               길듕이도 딱 원하는 자연스러움 컬링이라며만족 만족 대만족을 하네요      0
# 10524       10524  말해 모해 김해미용실추천 김해미용실 찾는다면던뮤어 헤어에서 도경 실장님을 찾아주세요...      0
# 10525       10525                                       지저분녀에서 깔끔녀로       0
# 10526       10526  증거사진 첨부합니다전 월에 클리닉 받으러 또 방문예정이구요앞으론 머리관리에 좀 더 ...      0
#
#                                                tokenized
# ...

# %%
# 인스타, 블로그 데이터 불러오기
import pandas as pd
data= pd.read_csv('/content/drive/MyDrive/비타민_자율프로젝트/data.csv')
data
# Out:
#                                                     text  label
# 0      "제주 여행의 일정 중 한 곳이던\n서귀포 올레시장 먹거리로 아침겸 점심을 누리고 ...      1
# 1      "허기를 채우려고 감자 샐러드를\n먹어보니 보드랍고 꼬숩한 맛이 너무 좋았어요.\n...      1
# 2      "연이어 앞에 고등어구이는 이 날 간만에 즐겨봤어요.\n그냥 봤을 때는 평범한 비주...      1
# 3      "친구도 밥에 얹어서 가득 맛보더니\n맛있다며 감탄하더라고요.\n살코기만 먹어도 너...      1
# 4      "밑반찬에 나오는 미역국도 미역도\n알차고 삼삼하며 개운하니 떠먹기 좋았어요.\n저...      1
# ...                                                  ...    ...
# 20942  미사리 조정경기장핑크뮬리 만개했어요💕💘3인용자전거 존잼 미사리조정경기장  미사리  ...      0
# 20943  동편마을 카페인데음료당 귀여운 선인장을줘요! 귀여워서 기분좋아짐🥰😘😘 동편마을카페 ...      0
# 20944                 멍레터 받은 덜덜이에요 너무  귀엽다 🥰😘😘💕수정됨 · 64주      0
# 20945  87구공탄 연탄불고기✨🔥🔥 남친돈남친산🧡파불고기 양 보이시나요? 저만큼에 8천원이라...      0
# 20946  브런치🥗🥙✨연남동 마나올라나카프레제 샌드위치&프렌치토스트! 마나올라나  연남동마나올...      0
#
# [20947 rows x 2 columns]

# %% [markdown]
# #### 전처리 진행

# %%
# !pip install git+https://github.com/haven-jeon/PyKoSpacing.git
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Cloning https://github.com/haven-jeon/PyKoSpacing.git to /tmp/pip-req-build-vejslspb
#   Running command git clone --filter=blob:none --quiet https://github.com/haven-jeon/PyKoSpacing.git /tmp/pip-req-build-vejslspb
#   Resolved https://github.com/haven-jeon/PyKoSpacing.git to commit fc2eb9f7837c9f4d256560a47437f4c11decb934
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 511.8/511.8 MB 3.3 MB/s eta 0:00:00
# ...
#   Created wheel for pykospacing: filename=pykospacing-0.5-py3-none-any.whl size=2268650 sha256=1416c66b3f481bf9147c4c6ec1c189da2b9cf31f31f5168656795be7448df5dd
#   Stored in directory: /tmp/pip-ephem-wheel-cache-_rjq43zd/wheels/79/a0/33/16f2cd03d21f76a663f5d69a0b96f0351335385349136fbd03
# Successfully built pykospacing
# ...
#   Attempting uninstall: tensorflow
#     Found existing installation: tensorflow 2.9.2
# ...

# %%
# # 띄어쓰기 진행

# from pykospacing import Spacing
# spacing = Spacing(rules=['내돈내산'])

# data['text'] = [spacing(s) for s in data['text']]
# data
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-49-89af50f31f31> in <module>
#       1 # 띄어쓰기 진행
#       2
# ----> 3 from pykospacing import Spacing
#       4 spacing = Spacing(rules=['내돈내산'])
#       5
#
# ModuleNotFoundError: No module named 'pykospacing'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
# !pip install soynlp
# Out:
# WARNING: Ignoring invalid distribution -ensorflow (/usr/local/lib/python3.8/dist-packages)
# WARNING: Ignoring invalid distribution -ensorflow (/usr/local/lib/python3.8/dist-packages)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 416.8/416.8 KB 9.8 MB/s eta 0:00:00
# ...
# WARNING: Ignoring invalid distribution -ensorflow (/usr/local/lib/python3.8/dist-packages)
# ...
# WARNING: Ignoring invalid distribution -ensorflow (/usr/local/lib/python3.8/dist-packages)
# ...

# %%
# # 띄어쓰기 완료됨
# data=pd.read_csv('/content/drive/MyDrive/비타민_자율프로젝트/data6.csv')
# data
# Out:
#        Unnamed: 0                                               text  label
# 0               0        얼마 전에 연말을 맞이하여 새마음으로\n성신여대 미용실 모노라인에 다녀왔어요.      1
# 1               1  이번에 제가 방문했었던\n지나인헤어 본점이에요.\n참고로 위치는 보문역 5분출구로 ...      1
# 2               2  이번에 다녀온 곳은\n무트나인헤어!!\n성신여대입구역 1번 출구로 나와서\n공차 골...      1
# 3               3                      바로 헤어 더뷰입니다\n매장은 2층에 위치해 있습니다      1
# 4               4  요새 일이 너무 바빠서 미용실을\n못 간 지 꽤 오래되었더라고요.\n그래서 근처에 ...      1
# ...           ...                                                ...    ...
# 10522       10522  우와~~~~~ 우리 길듕이 원래 멋있었지만\n펌 하고 나니 멋짐이 UP! UP!\n...      0
# 10523       10523        길듕이도 딱 원하는 자연스러움, 컬링이라며\n만족, 만족 대~~만족을 하네요.      0
# 10524       10524  말해 모해! 김해미용실추천, 김해미용실 찾는다면\n던뮤어 헤어에서 도경 실장님을 찾...      0
# 10525       10525                                 "지저분녀"에서 "깔끔녀"로 ??      0
# 10526       10526  (증거사진 첨부합니다)\n전 12월에 클리닉 받으러 또 방문예정이구요,,\n앞으론 ...      0
#
# [10527 rows x 3 columns]

# %%
# 가-힣 외 제거
data['text'] = data['text'].str.replace("[^가-힣 ]","")
data
# Out:
# <ipython-input-370-78bf359e9c69>:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   data['text'] = data['text'].str.replace("[^가-힣 ]","")
#                                                     text  label
# 0      제주여행의 일정 중 한 곳이던 서귀포 올레시장 먹거리로 아침 겸 점심을 누리고 왔어...      1
# 1      허기를 채우려고 감자 샐러드를 먹어보니 보드랍고 꼬숩한 맛이 너무 좋았어요 기본 찬...      1
# 2      연이어 앞에 고등어 구이는 이날 간만에 즐겨봤어요 그냥 봤을 때는 평범한 비주얼인데...      1
# 3      친구도 밥에 얹어서 가득 맛보더니 맛있다며 감탄하더라고요 살코기만 먹어도 너무 맛있...      1
# 4      밑반찬에 나오는 미역국도 미역도 알차고 삼삼하며 개운하니 떠먹기 좋았어요 저는 한 ...      1
# ...                                                  ...    ...
# 31469  우와 우리 길듕이 원래 멋있었지만펌 하고 나니 멋짐이  길듕이 보다 제가 더 만족스...      0
# 31470               길듕이도 딱 원하는 자연스러움 컬링이라며만족 만족 대만족을 하네요      0
# 31471  말해 모해 김해미용실추천 김해미용실 찾는다면던뮤어 헤어에서 도경 실장님을 찾아주세요...      0
# 31472                                       지저분녀에서 깔끔녀로       0
# 31473  증거사진 첨부합니다전 월에 클리닉 받으러 또 방문예정이구요앞으론 머리관리에 좀 더 ...      0
#
# ...

# %%
# 반복되는 자모 제거
from soynlp.normalizer import *
for i in range (0,20947):
  try:
    data['text'][i]= repeat_normalize(data3['text'][i], num_repeats=2)
  except:
    pass

# %%
stopwords = ['도', '는', '다', '의', '가', '이', '은', '한', '에', '하', '고', '을', '를', '인', '듯', '과', '와', '네', '들', '듯', '지', '임', '게', '만', '게임', '겜', '되', '음', '면','있','어','어요','주','로','좋','수','먹','해','기','보','아','시','는데','으로','그램','기','아','었','요','했','에서','스타','것','니','어서','았','같','라','적','미용실','머리','더라고요','는데요','던','셨','헤어','님','잘','나','지만','습니다','죠','다는','받','거','저','제','때','할','분','서','원','까지','내산','겠','라고','셔서','아서','면서','그리고','답니다','아요','때문','보다','더라구요','서','내','해서','다고','트','여기','바로''더','된','이렇게','네요','성신','감','아니','니까','오','좀','세요','길','바로','점','그래서','신','보이','해요','여대','않','두','그','중','또','도록','없이','알','거든요']

# %%
# data['text'] = data['text'].astype('string')

# data

# %%
data = data.dropna()
data['text'].isnull().sum()
# Out:
# 0

# %%
mecab = Mecab() 

data['tokenized'] = data['text'].apply(mecab.morphs)
data['tokenized'] = data['tokenized'].apply(lambda x: [item for item in x if item not in stopwords])
data
# Out:
#        Unnamed: 0  Unnamed: 0.1  \
# 0               0             0
# 1               1             1
# 2               2             2
# 3               3             3
# 4               4             4
# ...           ...           ...
# 31442       31467         31469
# 31443       31468         31470
# 31444       31469         31471
# 31445       31470         31472
# 31446       31471         31473
#
#                                                     text  label  \
# 0      제주여행의 일정 중 한 곳이던 서귀포 올레시장 먹거리로 아침 겸 점심을 누리고 왔어...      1
# 1      허기를 채우려고 감자 샐러드를 먹어보니 보드랍고 꼬숩한 맛이 너무 좋았어요 기본 찬...      1
# 2      연이어 앞에 고등어 구이는 이날 간만에 즐겨봤어요 그냥 봤을 때는 평범한 비주얼인데...      1
# 3      친구도 밥에 얹어서 가득 맛보더니 맛있다며 감탄하더라고요 살코기만 먹어도 너무 맛있...      1
# 4      밑반찬에 나오는 미역국도 미역도 알차고 삼삼하며 개운하니 떠먹기 좋았어요 저는 한 ...      1
# ...                                                  ...    ...
# 31442  우와 우리 길듕이 원래 멋있었지만펌 하고 나니 멋짐이  길듕이 보다 제가 더 만족스...      0
# ...

# %%
negative_words = np.hstack(data[data.label == 0]['tokenized'].values)
positive_words = np.hstack(data[data.label == 1]['tokenized'].values)

# %%
#비광고
negative_word_count = Counter(negative_words)
print(negative_word_count.most_common(50))
# Out:
# [('맛집', 6670), ('맛', 6450), ('돈', 3956), ('안', 3914), ('추천', 3803), ('너무', 3791), ('맛있', 3677), ('팔', 3392), ('더', 3268), ('없', 3165), ('리뷰', 2387), ('됨', 2350), ('일', 2260), ('싶', 2249), ('번', 2238), ('맞', 2180), ('수정', 2178), ('느낌', 2164), ('시간', 2146), ('제품', 2113), ('집', 2021), ('많', 2016), ('진짜', 2016), ('가격', 2016), ('생각', 2003), ('구매', 1912), ('곳', 1899), ('타', 1859), ('정말', 1845), ('많이', 1792), ('사용', 1769), ('정도', 1766), ('입니다', 1689), ('카페', 1670), ('전', 1648), ('사진', 1641), ('였', 1629), ('후기', 1627), ('빵', 1533), ('메뉴', 1488), ('으면', 1481), ('말', 1463), ('편', 1430), ('신상', 1424), ('먹스', 1416), ('함', 1383), ('합니다', 1376), ('데', 1348), ('인데', 1345), ('랑', 1328)]

# %%
#광고
positive_word_count = Counter(positive_words)
print(positive_word_count.most_common(50))
# Out:
# [('제품', 6635), ('사용', 4908), ('맛', 4336), ('추천', 4294), ('너무', 4037), ('더', 4032), ('협찬', 3941), ('없', 3845), ('피부', 3233), ('시간', 3100), ('맛집', 3068), ('안', 3015), ('많', 2882), ('맛있', 2835), ('일', 2810), ('정말', 2691), ('됨', 2530), ('제공', 2524), ('수정', 2477), ('번', 2330), ('싶', 2305), ('생각', 2258), ('많이', 2116), ('곳', 2110), ('가능', 2075), ('집', 2072), ('느낌', 2020), ('등', 1932), ('남', 1929), ('전', 1902), ('성분', 1887), ('후', 1874), ('관리', 1830), ('맞', 1778), ('부터', 1776), ('팔', 1769), ('였', 1713), ('가지', 1706), ('크림', 1676), ('선물', 1664), ('함', 1659), ('향', 1638), ('아이', 1614), ('만들', 1531), ('진행', 1526), ('샴푸', 1466), ('펌', 1466), ('성', 1462), ('건강', 1461), ('광고', 1460)]

# %%
# '미용실','머리','더라고요','는데요','던','셨','헤어','님','잘','나','지만','습니다','죠','다는'

# '받','거','저','제','때','할','분','서','원','까지','내산','겠','라고','셔서','아서','면서','그리고','답니다','아요','때문','보다','더라구요','서'

# '내','해서','다고','트','여기','바로''더','된','이렇게','네요','성신','감','아니','니까'

# '오','좀','세요','길','바로','점','그래서','신','보이','해요','여대'

# '않','두','그','중','또','도록','없이','알','거든요'

# %%
fig,(ax1,ax2) = plt.subplots(1,2,figsize=(10,5))
text_len = data[data['label']==1]['tokenized'].map(lambda x: len(x))
ax1.hist(text_len, color='red')
ax1.set_title('Positive Reviews')
ax1.set_xlabel('length of samples')
ax1.set_ylabel('number of samples')
print('긍정 리뷰의 평균 길이 :', np.mean(text_len))

text_len = data[data['label']==0]['tokenized'].map(lambda x: len(x))
ax2.hist(text_len, color='blue')
ax2.set_title('Negative Reviews')
fig.suptitle('Words in texts')
ax2.set_xlabel('length of samples')
ax2.set_ylabel('number of samples')
print('부정 리뷰의 평균 길이 :', np.mean(text_len))
plt.show()
# Out:
# 긍정 리뷰의 평균 길이 : 59.14418663145319
# 부정 리뷰의 평균 길이 : 47.21844691373884

# %% [markdown]
# #### 전처리 토큰화 완료된 데이터로 진행

# %%
data.to_csv("/content/drive/MyDrive/비타민_자율프로젝트/data_30000.csv")

# %%
# data = pd.read_csv("/content/drive/MyDrive/비타민_자율프로젝트/data_30000.csv")
# data
# Out:
#        Unnamed: 0  Unnamed: 0.1  \
# 0               0             0
# 1               1             1
# 2               2             2
# 3               3             3
# 4               4             4
# ...           ...           ...
# 31442       31467         31469
# 31443       31468         31470
# 31444       31469         31471
# 31445       31470         31472
# 31446       31471         31473
#
#                                                     text  label  \
# 0      제주여행의 일정 중 한 곳이던 서귀포 올레시장 먹거리로 아침 겸 점심을 누리고 왔어...      1
# 1      허기를 채우려고 감자 샐러드를 먹어보니 보드랍고 꼬숩한 맛이 너무 좋았어요 기본 찬...      1
# 2      연이어 앞에 고등어 구이는 이날 간만에 즐겨봤어요 그냥 봤을 때는 평범한 비주얼인데...      1
# 3      친구도 밥에 얹어서 가득 맛보더니 맛있다며 감탄하더라고요 살코기만 먹어도 너무 맛있...      1
# 4      밑반찬에 나오는 미역국도 미역도 알차고 삼삼하며 개운하니 떠먹기 좋았어요 저는 한 ...      1
# ...                                                  ...    ...
# 31442  우와 우리 길듕이 원래 멋있었지만펌 하고 나니 멋짐이  길듕이 보다 제가 더 만족스...      0
# ...

# %%
# 8:2로 train, test 분리
train_data,test_data = train_test_split(data,test_size=0.2,random_state=42,stratify=data['label'].values)

# %%
# from sklearn.model_selection import train_test_split
# X_valid, X_test, y_valid, y_test = train_test_split(test_data['tokenized'].values,test_data['label'].values,test_size=0.5,random_state=3,stratify=test_data['label'].values)
# X_train = data['tokenized'].values
# y_train = data['label'].values

# %%
# df_all5는 토큰화 완료된 200여개 데이터

X_valid = df_all5['tokenized'].values
y_valid = df_all5['label'].values

X_test = test_data['tokenized'].values
y_test = test_data['label'].values

X_train = train_data['tokenized'].values
y_train = train_data['label'].values

# %%
len(X_valid),len(X_test)
# Out:
# (203, 6290)

# %%
tokenizer = Tokenizer()
tokenizer.fit_on_texts(X_train)

# %%
threshold = 3
total_cnt = len(tokenizer.word_index) # 단어의 수
rare_cnt = 0 # 등장 빈도수가 threshold보다 작은 단어의 개수를 카운트
total_freq = 0 # 훈련 데이터의 전체 단어 빈도수 총 합
rare_freq = 0 # 등장 빈도수가 threshold보다 작은 단어의 등장 빈도수의 총 합

# 단어와 빈도수의 쌍(pair)을 key와 value로 받는다.
for key, value in tokenizer.word_counts.items():
    total_freq = total_freq + value

    # 단어의 등장 빈도수가 threshold보다 작으면
    if(value < threshold):
        rare_cnt = rare_cnt + 1
        rare_freq = rare_freq + value

print('단어 집합(vocabulary)의 크기 :',total_cnt)
print('등장 빈도가 %s번 이하인 희귀 단어의 수: %s'%(threshold - 1, rare_cnt))
print("단어 집합에서 희귀 단어의 비율:", (rare_cnt / total_cnt)*100)
print("전체 등장 빈도에서 희귀 단어 등장 빈도 비율:", (rare_freq / total_freq)*100)
vocab_size = total_cnt - rare_cnt + 2
print('단어 집합의 크기 :',vocab_size)
# Out:
# 단어 집합(vocabulary)의 크기 : 43111
# 등장 빈도가 2번 이하인 희귀 단어의 수: 21260
# 단어 집합에서 희귀 단어의 비율: 49.314560089072394
# 전체 등장 빈도에서 희귀 단어 등장 빈도 비율: 2.0381466822025307
# 단어 집합의 크기 : 21853

# %%
tokenizer = Tokenizer(vocab_size, oov_token = 'OOV') 
tokenizer.fit_on_texts(X_train)
X_train = tokenizer.texts_to_sequences(X_train)

X_test = tokenizer.texts_to_sequences(X_test)
X_valid = tokenizer.texts_to_sequences(X_valid)

# %%
print(X_valid[:3])
# Out:
# [[63, 29, 12445, 1475, 1918, 175, 36, 450, 442, 1554, 985, 9, 235, 75, 7, 450, 12716, 67, 63, 14044, 440, 204, 232, 313, 666, 215, 8, 108, 1104, 63, 204, 232, 129, 1323, 753, 11038, 396, 691, 175, 3704, 1613, 426, 1554, 214, 151, 635, 71, 47, 936, 174, 1, 358, 1237, 1111, 817, 1237, 533, 1658, 174, 11944, 8, 14, 1621, 202, 85, 313, 437, 950, 139, 84, 21, 42], [12942, 30, 191, 226, 123, 464, 6, 368, 313, 1, 2175, 108, 970, 63, 1261, 666, 209, 8, 147, 695, 635, 71, 47, 209, 303, 233, 3678, 142, 450, 6, 187, 666, 338, 533, 8, 1149, 21465, 209, 90, 232, 396, 6553, 30, 8348, 202, 9, 85, 14044, 440, 544, 338, 1138, 1796, 8, 4670, 21, 48, 74, 2569, 1613, 246, 740, 8, 426, 67, 90, 147, 3568, 2569], [1104, 63, 465, 116, 34, 2883, 6, 313, 136, 2175, 407, 2356, 63, 215, 14044, 4001, 2972, 5786, 66, 878, 5403, 123, 666, 66, 9, 147, 1535, 192, 11685, 5267, 123, 204, 394, 178, 1092, 40, 147, 1686, 147, 123, 9180, 3531, 21, 48, 1]]

# %%
print('리뷰의 최대 길이 :',max(len(l) for l in X_train))
print('리뷰의 평균 길이 :',sum(map(len, X_train))/len(X_train))
plt.hist([len(s) for s in X_train], bins=50)
plt.xlabel('length of samples')
plt.ylabel('number of samples')
plt.show()
# Out:
# 리뷰의 최대 길이 : 432
# 리뷰의 평균 길이 : 23.893701909375892

# %%
def below_threshold_len(max_len, nested_list):
  cnt = 0
  for s in nested_list:
    if(len(s) <= max_len):
        cnt = cnt + 1
  print('전체 샘플 중 길이가 %s 이하인 샘플의 비율: %s'%(max_len, (cnt / len(nested_list))*100))

max_len = 400
below_threshold_len(max_len, X_train)
# Out:
# 전체 샘플 중 길이가 400 이하인 샘플의 비율: 99.90857415431093

# %%
# 데이터 패딩 넣어주기


X_train = pad_sequences(X_train, maxlen = max_len)
X_test = pad_sequences(X_test, maxlen = max_len)
X_valid = pad_sequences(X_valid , maxlen = max_len)

# %%
import re
from tensorflow.keras.layers import Embedding, Dense, LSTM, Bidirectional
from tensorflow.keras.models import Sequential
from tensorflow.keras.models import load_model
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

# %%
chkpoint_filepath = "/content/drive/MyDrive/비타민_자율프로젝트/hair_best_model_진짜진짜.h5"

model = Sequential()
model.add(Embedding(vocab_size, 100))
model.add(Bidirectional(LSTM(128)))
model.add(Dense(1, activation='sigmoid'))
mc = ModelCheckpoint(filepath = chkpoint_filepath, monitor='val_acc', mode='max', verbose=1, save_best_only=True)
model.compile(optimizer='rmsprop', loss='binary_crossentropy', metrics=['acc'])
history = model.fit(X_train, y_train, epochs=15, callbacks=[mc], batch_size=256, validation_data=(X_valid, y_valid))
# Out:
# Epoch 1/15
# 99/99 [==============================] - ETA: 0s - loss: 0.5177 - acc: 0.7470
# Epoch 1: val_acc improved from -inf to 0.65025, saving model to /content/drive/MyDrive/비타민_자율프로젝트/hair_best_model_진짜진짜.h5
# 99/99 [==============================] - 11s 84ms/step - loss: 0.5177 - acc: 0.7470 - val_loss: 0.6826 - val_acc: 0.6502
# Epoch 2/15
# 99/99 [==============================] - ETA: 0s - loss: 0.3207 - acc: 0.8673
# Epoch 2: val_acc improved from 0.65025 to 0.65517, saving model to /content/drive/MyDrive/비타민_자율프로젝트/hair_best_model_진짜진짜.h5
# 99/99 [==============================] - 7s 75ms/step - loss: 0.3207 - acc: 0.8673 - val_loss: 0.7116 - val_acc: 0.6552
# Epoch 3/15
# 99/99 [==============================] - ETA: 0s - loss: 0.2513 - acc: 0.9001
# Epoch 3: val_acc did not improve from 0.65517
# 99/99 [==============================] - 7s 74ms/step - loss: 0.2513 - acc: 0.9001 - val_loss: 0.8310 - val_acc: 0.6256
# Epoch 4/15
# ...

# %%
chkpoint_filepath = "/content/drive/MyDrive/비타민_자율프로젝트/hair_best_model_진짜진짜.h5"

loaded_model = load_model(chkpoint_filepath)
#print("테스트 정확도: %.4f" % (loaded_model.evaluate(X_test, y_test)[1]))

# %%
from sklearn.metrics import classification_report
th=0.26
y_pred = (loaded_model.predict(X_test)[:,0] >= th).astype(int)
print(classification_report(y_test, y_pred))
# Out:
# 50/50 [==============================] - 2s 21ms/step
#               precision    recall  f1-score   support
#
#            0       0.99      0.94      0.96       782
#            1       0.94      0.99      0.97       798
#
#     accuracy                           0.97      1580
#    macro avg       0.97      0.97      0.97      1580
# weighted avg       0.97      0.97      0.97      1580

# %%
from sklearn.metrics import classification_report
th=0.5
y_pred = (loaded_model.predict(X_test)[:,0] >= th).astype(int)
print(classification_report(y_test, y_pred))
# Out:
# 50/50 [==============================] - 1s 20ms/step
#               precision    recall  f1-score   support
#
#            0       0.98      0.98      0.98       782
#            1       0.98      0.98      0.98       798
#
#     accuracy                           0.98      1580
#    macro avg       0.98      0.98      0.98      1580
# weighted avg       0.98      0.98      0.98      1580

# %% [markdown]
# #### 테스트 데이터 확인

# %%
# 데이터 결과 나타내보기

test_data_se,test_data_sep = train_test_split(test_data,test_size=0.5,random_state=3,stratify=test_data['label'].values)
test_data_sep=test_data_sep.iloc[:30]
test_30=loaded_model.predict(X_test[:30])
test_data_sep=test_data_sep[['text','label']]
test_data_sep['result']=test_30
test_data_sep
# Out:
# 1/1 [==============================] - 0s 30ms/step
#                                                    text  label    result
# 4337   도화동미용실 내돈내산 고정현헤어 제물포미용실 고정현헤어앨리웨이인천점 초이디자이너 매직컬      0  0.000662
# 3416  제가 지루함을 못 견디는 편이라미용실에서 오래 앉아있지못하는데 이곳은 두 분께서작업...      1  0.998633
# 4476                                            셀카도 찍음       0  0.338684
# 446   여며색 시술 동안 제가 봤던 후기들 처럼 정말 꼼꼼히 잘 신경 써주셔서 너무 편하게...      1  0.935558
# 4806                                     다니실장님 명함도 하나 겟      0  0.341857
# 6261  진짜 몇년동안 나 뿐만아니라 우리엄마 이모머리까지 맡아 해 주시고 계시는 코난 대표...      0  0.000848
# 2675  김해율하 미용실의 담당 디자이너분이손상된 머리 끝 부분부터 정리를 해주셨어요빠르게 ...      1  0.999965
# 2894  펌이나 염색약이 알칼리 성분이라그와 반대인  산성 성분의 수분으로먼저 채워주고 계십...      1  0.995037
# 343   주변 대학생들도 많이 이용할듯뭣보다 단골이 진짜 많은 곳 같다들어갔는데 미용사쌤이랑...      1  0.983723
# 5104  기다리는 사람들을 위하여 마련된커피와 음료수들과일주스랑 바나나 초코우유가 있어서너무...      0  0.003321
# 2280  다른 곳에서 받아보지 못했던헤드스파를 받아주는데머리가 지끈거렸던 부분들도말끔히 해소...      1  0.999872
# ...

# %%
th=0.5
def review_evaluation_predict(predict_value):
    if predict_value<th:
      return "(부정 확률 : %.2f) 광고가 아닙니다." % (1-predict_value)
    else:
      return "(긍정 확률 : %.2f) 광고입니다." % predict_value

test_data_sep['eval']=test_data_sep['result'].apply(review_evaluation_predict)
test_data_sep.drop(columns=['result'],inplace=True)
test_data_sep.head(10)
# Out:
#                                                     text  label  \
# 17833  주소 부산 부산진구 골드테마길 전화번호  영업시간 매일  지난 주말 부산 갈일이 있...      0
# 6186   제품 명우디 체크 누빔 매트리스 커버 가격은 원 쿠팡에서 구매했어요 요즘 체크무늬가...      0
# 832    누렇고 찌든 때 들을 남김없이 빼줄 수가 있으며 아이들 옷에도 무리 없이 빨래한답니...      1
# 12734  제품 제공 안녕하세요 오늘 소개할 제품은 컬러 그램의 신제품 올인원 오버립 메이커 ...      1
# 18302  셀카 여름이랑 같이 오늘 따라 컷트와 면도 스타일링이 너무 만족스럽게 됨 역시 남자...      0
# 16637  편대리가 보고하는 기안 서편대리가 직접 주세븐일레븐에서 구입한  허니버터팝콘에 대한...      0
# 19247  내돈내산과 메기 늘 보과메기과메기 맛집과 메기 또 생각나서 시킴 기성초장 싫어서기성...      0
# 2210   현금사은품을 법적 한도 내에서 최고로 지급해주는 데다가 설치 당일 바로 들어와서 마...      1
# 5273   리프트는 어릴 때 타보고 안 타봤는데 막상 높이를 보니 꽤 겁이 나더라고요 그래도 ...      1
# 15106  협찬 셰프 애찬얼큰 수제 알탕 날이 추워지면 추워질수록 요 알탕이 그렇게 땡기더라구...      1
#
#                            eval
# 17833  (부정 확률 : 1.00) 광고가 아닙니다.
# 6186   (부정 확률 : 0.97) 광고가 아닙니다.
# 832       (긍정 확률 : 1.00) 광고입니다.
# 12734     (긍정 확률 : 1.00) 광고입니다.
# 18302  (부정 확률 : 1.00) 광고가 아닙니다.
# 16637  (부정 확률 : 1.00) 광고가 아닙니다.
# ...

# %% [markdown]
# #### 네이버지도 테스트

# %%
# 저장된 모델 불러오기
# chkpoint_filepath = "/content/drive/MyDrive/비타민_자율프로젝트/best_model.h5"

load_model = load_model(chkpoint_filepath)

# %%
# 비광고 은비
import pandas as pd

df4 = pd.read_csv("/content/drive/MyDrive/비타민_자율프로젝트/네이버지도_광고리뷰_유정_수정.csv")

df4.head()
# Out:
#                                                 text  label
# 0  🔮너무 마음에 들어요🔮 다이슨 에어랩 하고 4시간 정도 지나서 적당히 풀린 듯한 깔...      1
# 1  레이어드컷 처음 해봤는데 너무 예쁘고 만족스럽게 잘됐어요 감사합니다!\n정말 상담도...      1
# 2  너어어어어어무 예뻐요 너무너무너무\n이제 머리 감고 그냥 풀고 다닐 수 있어서 너무...      1
# 3  솜브레로 탈색과 염색하고 얇아진 모발에 딱이던 스페셜 클리닉. 꼬모레비로 받았어요....      1
# 4  헤그리드--->참한 여인 헤어 시술 받구 지금 제가 느낀 감정이예요! 타샵에서 무지...      1

# %%
df2 = df2[['content','label']]
df2 = df2.rename(columns={'content':'text'})
df2.head()
# Out:
#                                                 text  label
# 0  검은 머리가 너무 지겨워서 애쉬베이지 솜브레염색을 해봤어요~ 처음 해보는 염색인데 ...      0
# 1  애쉬베이지 발레아쥬 염색을 해보았습니다. 이름도 어려운데 ! 엄청난 스킬이 느껴지는...      0
# 2  몇년동안 탈색머리유지하다가 블랙으로 단정하게 바꿔봤어요 탈색으로 머릿결상해있어서 와...      0
# 3  시세이도모발클리닉 후 스타일링받았습니다 원하는대로 자연스럽고 여성스럽게 잘 해주셔서...      0
# 4  애즈펌 처음해봤는데 너무 마음에 들어요!! 머리 손질도 더 쉬워졌어요. 깔끔하게 해...      0

# %%
# from pykospacing import Spacing
# spacing = Spacing(rules=['내돈내산'])


# 가-힣 외 제거
df_all5['text'] = df_all5['text'].str.replace("[^가-힣 ]","")

# data['text'] = [spacing(s) for s in data['text']]

# 반복되는 자모 제거
from soynlp.normalizer import *
for i in range (0,20947):
  try:
    df_all5['text'][i]= repeat_normalize(df_all5['text'][i], num_repeats=2)
  except:
    pass

# 토큰화
mecab = Mecab()
df_all5['tokenized'] = df_all5['text'].apply(mecab.morphs)
df_all5['tokenized'] = df_all5['tokenized'].apply(lambda x: [item for item in x if item not in stopwords])

df_all5
# Out:
# <ipython-input-416-eb4383480c19>:6: FutureWarning: The default value of regex will change from True to False in a future version.
#   df_all5['text'] = df_all5['text'].str.replace("[^가-힣 ]","")
# <ipython-input-416-eb4383480c19>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_all5['text'][i]= repeat_normalize(df_all5['text'][i], num_repeats=2)
# <ipython-input-416-eb4383480c19>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_all5['text'][i]= repeat_normalize(df_all5['text'][i], num_repeats=2)
# <ipython-input-416-eb4383480c19>:14: SettingWithCopyWarning:
# ...

# %%
# numpy
#X_train = test_ad['tokenized'].values
# tokenizer = Tokenizer()
# tokenizer.fit_on_texts(X_train)
#tokenizer.fit_on_texts(data['tokenized'].values)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-93-19f92e615b7c> in <module>
#       2 # X_train = data['tokenized'].values
#       3 tokenizer = Tokenizer()
# ----> 4 tokenizer.fit_on_texts(X_train)
#       5 #tokenizer.fit_on_texts(data['tokenized'].values)
#
# /usr/local/lib/python3.8/dist-packages/keras/preprocessing/text.py in fit_on_texts(self, texts)
#     277       else:
#     278         if self.analyzer is None:
# --> 279           seq = text_to_word_sequence(
#     280               text, filters=self.filters, lower=self.lower, split=self.split)
#     281         else:
#
# /usr/local/lib/python3.8/dist-packages/keras/preprocessing/text.py in text_to_word_sequence(input_text, filters, lower, split)
#      70   """
#      71   if lower:
# ---> 72     input_text = input_text.lower()
#      73
#      74   translate_dict = {c: split for c in filters}
#
# ...

# %%
threshold = 3
total_cnt = len(tokenizer.word_index) # 단어의 수
rare_cnt = 0 # 등장 빈도수가 threshold보다 작은 단어의 개수를 카운트
total_freq = 0 # 훈련 데이터의 전체 단어 빈도수 총 합
rare_freq = 0 # 등장 빈도수가 threshold보다 작은 단어의 등장 빈도수의 총 합

# 단어와 빈도수의 쌍(pair)을 key와 value로 받는다.
for key, value in tokenizer.word_counts.items():
    total_freq = total_freq + value

    # 단어의 등장 빈도수가 threshold보다 작으면
    if(value < threshold):
        rare_cnt = rare_cnt + 1
        rare_freq = rare_freq + value

print('단어 집합(vocabulary)의 크기 :',total_cnt)
print('등장 빈도가 %s번 이하인 희귀 단어의 수: %s'%(threshold - 1, rare_cnt))
print("단어 집합에서 희귀 단어의 비율:", (rare_cnt / total_cnt)*100)
print("전체 등장 빈도에서 희귀 단어 등장 빈도 비율:", (rare_freq / total_freq)*100)
vocab_size = total_cnt - rare_cnt + 2
print('단어 집합의 크기 :',vocab_size)

# %%
vocab_size
# Out:
# 22615

# %%
# data3 = pd.read_csv('/content/drive/MyDrive/비타민_자율프로젝트/data3.csv')
# data3
# Out:
#        label                                               text
# 0          1  제주여행의 일정 중 한 곳이던 서귀포 올레시장 먹거리로 아침 겸 점심을 누리고 왔어...
# 1          1  허기를 채우려고 감자 샐러드를 먹어보니 보드랍고 꼬숩한 맛이 너무 좋았어요 기본 찬...
# 2          1  연이어 앞에 고등어 구이는 이날 간만에 즐겨봤어요 그냥 봤을 때는 평범한 비주얼인데...
# 3          1  친구도 밥에 얹어서 가득 맛보더니 맛있다며 감탄하더라고요 살코기만 먹어도 너무 맛있...
# 4          1  밑반찬에 나오는 미역국도 미역도 알차고 삼삼하며 개운하니 떠먹기 좋았어요 저는 한 ...
# ...      ...                                                ...
# 20942      0  미사리 조정경기장 핑크뮬리만개했어요 3인용 자전거 존 잼미사리 조정경기장 미사리 하...
# 20943      0  동편마을 카페인데 음료당 귀여운 선인장을 줘 요귀여워서 기분 좋아짐 동편마을 카페인...
# 20944      0                      멍레터 받은 덜덜 이에 요 너무 귀엽 다수정됨 64주
# 20945      0  87구 공탄 연탄불 고기 남친 돈남친산파 불고기 양보이시나 요저만큼에 8천원이라니 ...
# 20946      0  브런치 연남동 마나올라나 카프레제샌드위치 프렌치 토스트마나 올라나 연남동 마나올라나...
#
# [20947 rows x 2 columns]

# %%
# 원래 직접 만들어야 함
# tokenizer = Tokenizer(22615, oov_token = 'OOV') 

# tokenizer.fit_on_texts(test_ad['tokenized'].values)
# #X_train = tokenizer.texts_to_sequences(X_train)

# X_test = tokenizer.texts_to_sequences(test_ad['tokenized'].values)

# %%
X_test = tokenizer.texts_to_sequences(df_all5['tokenized'].values)

# %%
print(X_test[:3])
# Out:
# [[63, 29, 12445, 1475, 1918, 175, 36, 450, 442, 1554, 985, 9, 235, 75, 7, 450, 12716, 67, 63, 14044, 440, 204, 232, 313, 666, 215, 8, 108, 1104, 63, 204, 232, 129, 1323, 753, 11038, 396, 691, 175, 3704, 1613, 426, 1554, 214, 151, 635, 71, 47, 936, 174, 1, 358, 1237, 1111, 817, 1237, 533, 1658, 174, 11944, 8, 14, 1621, 202, 85, 313, 437, 950, 139, 84, 21, 42], [12942, 30, 191, 226, 123, 464, 6, 368, 313, 1, 2175, 108, 970, 63, 1261, 666, 209, 8, 147, 695, 635, 71, 47, 209, 303, 233, 3678, 142, 450, 6, 187, 666, 338, 533, 8, 1149, 21465, 209, 90, 232, 396, 6553, 30, 8348, 202, 9, 85, 14044, 440, 544, 338, 1138, 1796, 8, 4670, 21, 48, 74, 2569, 1613, 246, 740, 8, 426, 67, 90, 147, 3568, 2569], [1104, 63, 465, 116, 34, 2883, 6, 313, 136, 2175, 407, 2356, 63, 215, 14044, 4001, 2972, 5786, 66, 878, 5403, 123, 666, 66, 9, 147, 1535, 192, 11685, 5267, 123, 204, 394, 178, 1092, 40, 147, 1686, 147, 123, 9180, 3531, 21, 48, 1]]

# %%
max_len = 400
X_test = pad_sequences(X_test, maxlen = max_len)

# %%
# 높이면 비광고 증가
th=0.5
def review_evaluation_predict(predict_value):
    if predict_value<th:
      return "(부정 확률 : %.2f) 광고가 아닙니다." % (1-predict_value)
    else:
      return "(긍정 확률 : %.2f) 광고입니다." % predict_value
def review_evaluation_predict2(predict_value):
    if predict_value<th:
      return 0
    else:
      return 1

test_30=loaded_model.predict(X_test)
test2 = df_all5[['text','tokenized','label']]
test2['result']=test_30
test2
# Out:
# 7/7 [==============================] - 0s 31ms/step
# <ipython-input-473-d6c69ae5797a>:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test2['result']=test_30
#                                                  text  \
# 0   펌이 많이 풀려서 무려 한지 년정도 되었는데도 컬이 유지가 되었지요솔직히 안해도 되...
# 1   여름휴가 전에 머리하러 왔는데용 항상 너무 친절하시고 머리도 예쁘게 원하는대루 해주...
# 2   앞머리펌과 뿌리염색을 하였습니당 너무 예쁘고 맘에들어용 모든 머리를 잘 하시지만 히...
# 3   연말이 되어서 머리도 변화를 줘야될것같아서 살롱오디너리 서우부원장님을 방문했는데용 ...
# 4   여자머리맛집입니당 요기 서우쌤 정말 머리 잘해주세용 머릿결도 안상하구 항상 친절하십...
# ..                                                ...
# 45  항상 방문할때마다 즐겁고 예쁘게 머리해서 기분좋게 가는거 같아요 항상 감사하고 머릿...
# 46  탈색 맛집 입니다 얼룩지는곳도 하나 없고 무엇보다 머릿결 손상이 안되고 너무 부드럽...
# 47  펌이 잘 안나오는 머리로 유명했는데 잘해주신 덕분에 어느덧 년째 단골이네요  누구보...
# ...

# %%
test2['eval'] = [review_evaluation_predict2(s) for s in test2['result']]

test2
# Out:
# <ipython-input-474-1a292afb3755>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test2['eval'] = [review_evaluation_predict2(s) for s in test2['result']]
#                                                  text  \
# 0   펌이 많이 풀려서 무려 한지 년정도 되었는데도 컬이 유지가 되었지요솔직히 안해도 되...
# 1   여름휴가 전에 머리하러 왔는데용 항상 너무 친절하시고 머리도 예쁘게 원하는대루 해주...
# 2   앞머리펌과 뿌리염색을 하였습니당 너무 예쁘고 맘에들어용 모든 머리를 잘 하시지만 히...
# 3   연말이 되어서 머리도 변화를 줘야될것같아서 살롱오디너리 서우부원장님을 방문했는데용 ...
# 4   여자머리맛집입니당 요기 서우쌤 정말 머리 잘해주세용 머릿결도 안상하구 항상 친절하십...
# ..                                                ...
# 45  항상 방문할때마다 즐겁고 예쁘게 머리해서 기분좋게 가는거 같아요 항상 감사하고 머릿...
# 46  탈색 맛집 입니다 얼룩지는곳도 하나 없고 무엇보다 머릿결 손상이 안되고 너무 부드럽...
# 47  펌이 잘 안나오는 머리로 유명했는데 잘해주신 덕분에 어느덧 년째 단골이네요  누구보...
# ...

# %%
sum = 0
for i in range(len(test2)):
  if test2['label'][i] ==test2['eval'][i]:
    sum +=1

print(sum/2)
# Out:
# 66.5

# %%
test2.to_csv('/content/drive/MyDrive/비타민_자율프로젝트/네이버지도valid_ver.csv')

# %%
'''
유정 광고 27/50

# 성우 비광고 32/50


은비 비광고 36/50

청수 광고 21/50


'''
# Out:
# '\n\n유정 광고 27/50\n\n# 성우 비광고 32/50\n\n\n은비 비광고 36/50\n\n청수 광고 21/50\n\n\n'

# %%
'''
<비광고>
성우
50개 중 
50 : 0

은비 
53개 중
53 : 0

<광고>
청수



'''
# Out:
# '\n<비광고>\n성우\n50개 중 \n50 : 0\n\n은비 \n53개 중\n53 : 0\n\n<광고>\n청수\n\n\n\n'

# %%
'''


1. 테스트 데이터와 학습 데이터의 차이를 줄인다.

2. 






'''
