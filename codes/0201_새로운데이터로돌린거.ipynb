# %%
import pandas as pd
import numpy as np
import torch
import re
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize 
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
import warnings
warnings.filterwarnings('ignore')

# %%
df1=pd.read_csv('/content/drive/MyDrive/비타민 프로젝트/미용실데이터최종.csv')

# %%
df1['label'].value_counts()
# Out:
# 0    5211
# 1    3778
# Name: label, dtype: int64

# %%
df2=pd.read_csv('/content/drive/MyDrive/비타민 프로젝트/hear_ad_data_6000.csv')

# %%
df2.drop_duplicates(subset='text',inplace=True,ignore_index=True)

# %%
df2
# Out:
#                                                    text  Unnamed: 1  \
# 0           얼마 전에 연말을 맞이하여 새마음으로\n성신여대 미용실 모노라인에 다녀왔어요.         NaN
# 1     이번에 제가 방문했었던\n지나인헤어 본점이에요.\n참고로 위치는 보문역 5분출구로 ...         NaN
# 2     이번에 다녀온 곳은\n무트나인헤어!!\n성신여대입구역 1번 출구로 나와서\n공차 골...         NaN
# 3                         바로 헤어 더뷰입니다\n매장은 2층에 위치해 있습니다         NaN
# 4     요새 일이 너무 바빠서 미용실을\n못 간 지 꽤 오래되었더라고요.\n그래서 근처에 ...         NaN
# ...                                                 ...         ...
# 5313  + #내돈내산 후기\n#동탄미용실 #반송동미용실 #준오헤어 #준오헤어동탄타임테라스점...         NaN
# 5314  방배 미용실은 샴푸실도\n엄청 예쁘게 꾸며져 있더라구요.\n다른 미용실들과는 달리\...         NaN
# 5315            주소\n서울 영등포구 영중로 18\n연락처\n0507-1493-0608         NaN
# 5316                                 준오헤어 포스코사거리점 위치에요!         NaN
# 5317  마포미용실 남자머리 하러 온 준오헤어 합정메세나폴리스점은 합정역 9번출구에서 이어지...         NaN
#
#       Unnamed: 2
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# ...          ...
# 5313         NaN
# ...

# %%
df2.drop(['Unnamed: 1','Unnamed: 2'],axis=1,inplace=True)

# %%
df2['label']=1

# %%
df2.dropna(axis=0,inplace=True)

# %%
df2
# Out:
#                                                    text  label
# 0           얼마 전에 연말을 맞이하여 새마음으로\n성신여대 미용실 모노라인에 다녀왔어요.      1
# 1     이번에 제가 방문했었던\n지나인헤어 본점이에요.\n참고로 위치는 보문역 5분출구로 ...      1
# 2     이번에 다녀온 곳은\n무트나인헤어!!\n성신여대입구역 1번 출구로 나와서\n공차 골...      1
# 3                         바로 헤어 더뷰입니다\n매장은 2층에 위치해 있습니다      1
# 4     요새 일이 너무 바빠서 미용실을\n못 간 지 꽤 오래되었더라고요.\n그래서 근처에 ...      1
# ...                                                 ...    ...
# 5313  + #내돈내산 후기\n#동탄미용실 #반송동미용실 #준오헤어 #준오헤어동탄타임테라스점...      1
# 5314  방배 미용실은 샴푸실도\n엄청 예쁘게 꾸며져 있더라구요.\n다른 미용실들과는 달리\...      1
# 5315            주소\n서울 영등포구 영중로 18\n연락처\n0507-1493-0608      1
# 5316                                 준오헤어 포스코사거리점 위치에요!      1
# 5317  마포미용실 남자머리 하러 온 준오헤어 합정메세나폴리스점은 합정역 9번출구에서 이어지...      1
#
# [5317 rows x 2 columns]

# %%
data= pd.concat([df1, df2],ignore_index=True)

# %%
data.drop_duplicates(subset='text',inplace=True,ignore_index=True)

# %%
data['label'].value_counts()
# Out:
# 1    5314
# 0    5209
# Name: label, dtype: int64

# %%
data.to_csv('/content/drive/MyDrive/비타민 프로젝트/미용실데이터최종.csv', index = False)

# %%
# !proper installation of python3
# !proper installation of pip

# !pip install tensorflow
# !pip install keras

# !pip install git+https://github.com/haven-jeon/PyKoSpacing.git
# Out:
# /bin/bash: proper: command not found
# /bin/bash: proper: command not found
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Cloning https://github.com/haven-jeon/PyKoSpacing.git to /tmp/pip-req-build-qnxi8a6l
#   Running command git clone --filter=blob:none --quiet https://github.com/haven-jeon/PyKoSpacing.git /tmp/pip-req-build-qnxi8a6l
#   Resolved https://github.com/haven-jeon/PyKoSpacing.git to commit fc2eb9f7837c9f4d256560a47437f4c11decb934
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 511.8/511.8 MB 3.3 MB/s eta 0:00:00
# ...
#   Created wheel for pykospacing: filename=pykospacing-0.5-py3-none-any.whl size=2268650 sha256=3f845ea7a19042fd7041a15975854a476e0816273515a20b829343d34cec52d8
# ...

# %%
data
# Out:
#                                                     text  label
# 0      솔리체헤어\n055-337-2797\n경남 김해시 경원로73번길 15\n경보더숨시티...      0
# 1      이정도 길이였는데, 이때 머리 예쁘게 잘라주셔서\n엄청 좋았더라는\n이때 머리 마음...      0
# 2                            나의 최애\n#증평미용실추천\n#증평미용실내돈내산      0
# 3      미사역에서 완전 가까워요!!\n전 항상 차량을 가져가는데\n주차도 무료이고,\n자리...      0
# 4      고잔동 aw컨벤션근처에있는\n고잔동헤어썸~~\n여기는 예약필수!!\n인기가 많은 미...      0
# ...                                                  ...    ...
# 10518  + #내돈내산 후기\n#동탄미용실 #반송동미용실 #준오헤어 #준오헤어동탄타임테라스점...      1
# 10519  방배 미용실은 샴푸실도\n엄청 예쁘게 꾸며져 있더라구요.\n다른 미용실들과는 달리\...      1
# 10520            주소\n서울 영등포구 영중로 18\n연락처\n0507-1493-0608      1
# 10521                                 준오헤어 포스코사거리점 위치에요!      1
# 10522  마포미용실 남자머리 하러 온 준오헤어 합정메세나폴리스점은 합정역 9번출구에서 이어지...      1
#
# [10523 rows x 2 columns]

# %%
#데이터 공백 제거
for i in range (0,8989):
  data['text'][i] = data['text'][i].replace(" ", "")

# %%
df_all5
# Out:
#                                                   text  label
# 0    🔮너무 마음에 들어요🔮 다이슨 에어랩 하고 4시간 정도 지나서 적당히 풀린 듯한 깔...      1
# 1    레이어드컷 처음 해봤는데 너무 예쁘고 만족스럽게 잘됐어요 감사합니다!\n정말 상담도...      1
# 2    너어어어어어무 예뻐요 너무너무너무\n이제 머리 감고 그냥 풀고 다닐 수 있어서 너무...      1
# 3    솜브레로 탈색과 염색하고 얇아진 모발에 딱이던 스페셜 클리닉. 꼬모레비로 받았어요....      1
# 4    헤그리드--->참한 여인 헤어 시술 받구 지금 제가 느낀 감정이예요! 타샵에서 무지...      1
# ..                                                 ...    ...
# 198  계속 미루다가 뿌리 엄청 지저분한 상태로 갔는데 너무 깨끗하게 정리해주셨어요! 내일...      0
# 199  성령 수석 실장님께서 이쁘게 잘라주셔서 매번 만족합니다~ 방문 때마다 친철하심은 물...      0
# 200  성령 실장님 이쁘게 잘 잘라주셔서 감사해요~!😍 늘 믿고 맡깁니다~ 머리를 항상 너...      0
# 201  오늘은 뿌리염색&신데렐라클리닉& 두피스케일링하러 왔어요, 정기적으로 오는 이곳🤍 올...      0
# 202  항상 갈때마다 100% 만족입니다! 염색이나 펌은 3-4개월에 한번씩 그리고 영양관...      0
#
# [203 rows x 2 columns]

# %%
for i in range (0,203):
  df_all5['text'][i] = df_all5['text'][i].replace(" ", "")

# %%
data
# Out:
#                                                     text  label
# 0      솔리체헤어\n055-337-2797\n경남김해시경원로73번길15\n경보더숨시티2층207호      0
# 1        이정도길이였는데,이때머리예쁘게잘라주셔서\n엄청좋았더라는\n이때머리마음에들었었는데???      0
# 2                             나의최애\n#증평미용실추천\n#증평미용실내돈내산      0
# 3      미사역에서완전가까워요!!\n전항상차량을가져가는데\n주차도무료이고,\n자리도늘비어있어...      0
# 4      고잔동aw컨벤션근처에있는\n고잔동헤어썸~~\n여기는예약필수!!\n인기가많은미용실인가...      0
# ...                                                  ...    ...
# 10518  + #내돈내산 후기\n#동탄미용실 #반송동미용실 #준오헤어 #준오헤어동탄타임테라스점...      1
# 10519  방배 미용실은 샴푸실도\n엄청 예쁘게 꾸며져 있더라구요.\n다른 미용실들과는 달리\...      1
# 10520            주소\n서울 영등포구 영중로 18\n연락처\n0507-1493-0608      1
# 10521                                 준오헤어 포스코사거리점 위치에요!      1
# 10522  마포미용실 남자머리 하러 온 준오헤어 합정메세나폴리스점은 합정역 9번출구에서 이어지...      1
#
# [10523 rows x 2 columns]

# %%
# 띄어쓰기 
from pykospacing import Spacing
spacing = Spacing(rules=['내돈내산'])

for i in range (0,10523):
  data['text'][i] = spacing(data['text'][i])

# %%
# 띄어쓰기 
from pykospacing import Spacing
spacing = Spacing(rules=['내돈내산'])

for i in range (0,10523):
  df_all5['text'][i] = spacing(df_all5['text'][i])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /usr/local/lib/python3.8/dist-packages/pandas/core/indexes/range.py in get_loc(self, key, method, tolerance)
#     384                 try:
# --> 385                     return self._range.index(new_key)
#     386                 except ValueError as err:
#
# ValueError: 203 is not in range
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-24-d1c529282e06> in <module>
#       4
#       5 for i in range (0,10523):
# ----> 6   df_all5['text'][i] = spacing(df_all5['text'][i])
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/series.py in __getitem__(self, key)
#     940
#     941         elif key_is_scalar:
# --> 942             return self._get_value(key)
#     943
#     944         if is_hashable(key):
#
# ...

# %%
data['text']=data['text'].astype(str)

# %%
df_all5['text']=df_all5['text'].astype(str)

# %%
data
# Out:
#                                                     text  label
# 0      솔리체 헤어 055-337-2797 경남 김해시 경원로73번길 15 경보 더 숨시티...      0
# 1      이 정도 길이였는데, 이때 머리 예쁘게 잘라주셔서 엄청 좋았더라는 이때 머리 마음에...      0
# 2                          나의 최애 #증평 미용실 추천 #증평 미용실 내돈내산      0
# 3      미사역에서 완전 가까워 요!! 전 항상 차량을 가져가는 데 주차도 무료이고, 자리도...      0
# 4      고잔동 aw 컨벤션 근처에 있는 고잔동 헤어썸~~ 여기는 예약 필수!! 인기가 많은...      0
# ...                                                  ...    ...
# 10518  + #내돈내산 후기 #동탄 미용실 #반송동 미용실 #준오헤어 #준오헤어 동탄타임테라...      1
# 10519  방배 미용실은 샴푸 실도 엄청 예쁘게 꾸며져 있더라구요. 다른 미용실들과는 달리 샴...      1
# 10520               주소 서울 영등포구 영중로 18 연락처 0507-1493-0608      1
# 10521                               준오헤어 포스코 사거리점 위치에 요!      1
# 10522  마포 미용실 남자 머리 하러 온 준오헤어 합정 메세나폴리스점은 합정역 9번 출구에서...      1
#
# [10523 rows x 2 columns]

# %%
# !pip install kss
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.7/77.7 KB 3.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 131.3/131.3 KB 7.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 26.4/26.4 MB 38.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for kss: filename=kss-4.5.1-py3-none-any.whl size=53218 sha256=83a9d314b60f03e7a3aac5c2ec7546e1396ca49b4e7250fa0440381e85b050d9
#   Stored in directory: /root/.cache/pip/wheels/8c/f9/05/a93eb0defc9eed494ee4d42e3d9076fade98f08982f41cf09f
# ...
#   Created wheel for pecab: filename=pecab-1.0.8-py3-none-any.whl size=26646667 sha256=5527c09a1f73c9f128db2fc46a71e19dc3b10186d0ce6190bc9ca5016b35ed05
#   Stored in directory: /root/.cache/pip/wheels/a9/98/a3/085a909aa25805f321467a3af3b80d43b6094ed335b4818775
# Successfully built kss pecab
# ...

# %%
data['text']=data['text'].astype(str)

# %%
data
# Out:
#                                                     text  label
# 0      솔리체 헤어 055-337-2797 경남 김해시 경원로73번길 15 경보 더 숨시티...      0
# 1      이 정도 길이였는데, 이때 머리 예쁘게 잘라주셔서 엄청 좋았더라는 이때 머리 마음에...      0
# 2                          나의 최애 #증평 미용실 추천 #증평 미용실 내돈내산      0
# 3      미사역에서 완전 가까워 요!! 전 항상 차량을 가져가는 데 주차도 무료이고, 자리도...      0
# 4      고잔동 aw 컨벤션 근처에 있는 고잔동 헤어썸~~ 여기는 예약 필수!! 인기가 많은...      0
# ...                                                  ...    ...
# 10518  + #내돈내산 후기 #동탄 미용실 #반송동 미용실 #준오헤어 #준오헤어 동탄타임테라...      1
# 10519  방배 미용실은 샴푸 실도 엄청 예쁘게 꾸며져 있더라구요. 다른 미용실들과는 달리 샴...      1
# 10520               주소 서울 영등포구 영중로 18 연락처 0507-1493-0608      1
# 10521                               준오헤어 포스코 사거리점 위치에 요!      1
# 10522  마포 미용실 남자 머리 하러 온 준오헤어 합정 메세나폴리스점은 합정역 9번 출구에서...      1
#
# [10523 rows x 2 columns]

# %%
#한국어 문장분리 파이썬 라이브러리 kss
import kss
for i in range (0,10523):
  data['text'][i] = kss.split_sentences(data['text'][i])

# %%
import kss
for i in range (0,203):
  df_all5['text'][i] = kss.split_sentences(df_all5['text'][i])
# Out:
# WARNING:root:Oh! You have mecab in your environment. Kss will take this as a backend! :D

# %%
data['text']=data['text'].astype(str)

# %%
df_all5['text']=df_all5['text'].astype(str)

# %%
data
# Out:
#                                                     text  label
# 0      ['솔리체 헤어 055-337-2797 경남 김해시 경원로73번길 15 경보 더 숨...      0
# 1      ['이 정도 길이였는데, 이때 머리 예쁘게 잘라주셔서 엄청 좋았더라는 이때 머리 마...      0
# 2                      ['나의 최애 #증평 미용실 추천 #증평 미용실 내돈내산']      0
# 3      [['미사역에서 완전 가까워 요!!'], ['전 항상 차량을 가져가는 데 주차도 무...      0
# 4      [['고잔동 aw 컨벤션 근처에 있는 고잔동 헤어썸~~ 여기는 예약 필수!!'], ...      0
# ...                                                  ...    ...
# 10518  ['+ #내돈내산 후기 #동탄 미용실 #반송동 미용실 #준오헤어 #준오헤어 동탄타임...      1
# 10519  [['방배 미용실은 샴푸 실도 엄청 예쁘게 꾸며져 있더라구요.'], ['다른 미용실...      1
# 10520           ['주소 서울 영등포구 영중로 18 연락처 0507-1493-0608']      1
# 10521                           ['준오헤어 포스코 사거리점 위치에 요!']      1
# 10522  [['마포 미용실 남자 머리 하러 온 준오헤어 합정 메세나폴리스점은 합정역 9번 출...      1
#
# [10523 rows x 2 columns]

# %%
#한글 아닌건 다 제거 
p= re.compile('[^가-힣]+')
for i in range (0,10523):
  data['text'][i]=p.sub(" ",data['text'][i])

# %%
#한글 아닌건 다 제거 
p= re.compile('[^가-힣]+')
for i in range (0,203):
  df_all5['text'][i]=p.sub(" ",df_all5['text'][i])

# %%
data.to_csv('/content/drive/MyDrive/비타민 프로젝트/미용실데이터만전처리.csv', index = False)

# %%
df_all5.to_csv('/content/drive/MyDrive/비타민 프로젝트/df_all5.csv', index = False)

# %%
df3=pd.read_csv('/content/drive/MyDrive/비타민 프로젝트/data10.csv')

# %%
dffinal= pd.concat([df3, data],ignore_index=True)

# %%
#dffinal.to_csv('/content/drive/MyDrive/비타민 프로젝트/data12.csv', index = False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-d1f7b1bfd6fb> in <module>
# ----> 1 dffinal.to_csv('/content/drive/MyDrive/비타민 프로젝트/data12.csv', index = False)
#
# NameError: name 'dffinal' is not defined

# %%
import pandas as pd
import numpy as np
import torch
import re
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize 
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
import warnings
warnings.filterwarnings('ignore')

# %%
data=pd.read_csv('/content/drive/MyDrive/비타민 프로젝트/data12.csv')

# %%
#df_all5=pd.read_csv('/content/drive/MyDrive/비타민 프로젝트/네이버지도테스트최종데이터2.csv')

# %%
dfall5=pd.read_csv('/content/drive/MyDrive/비타민 프로젝트/df_all5.csv')

# %%
dfall5
# Out:
#                                                   text  label
# 0     너무 마음에 들어 요 다이슨 에어랩하고 시간 정도 지나서 적당히 풀린 듯한 깔끔하...      1
# 1     레이어드 컷 처음 해봤는데 너무 예쁘고 만족스럽게 잘 됐어요 감사합니다 정말 상담...      1
# 2     너어어어어어무 예뻐 요 너무너 무너무 이제 머리 감고 그냥 풀고 다닐 수 있어서 ...      1
# 3     솜브레로 탈색과 염색하고 얇아진 모발에 딱 이던 스페셜 클리닉 꼬모레비로 받았어요...      1
# 4     헤그리드 참 한 여인 헤어 시술 받구 지금 제가 느낀 감정이예요 타샵에서 무지무지...      1
# ..                                                 ...    ...
# 198   계속 미루다가 뿌리엄 청지저분한 상태로 갔는데 너무 깨끗하게 정리해주셨어요 내일 ...      0
# 199   성령수석실장님께서 이쁘게 잘라주셔서 매번 만족합니다 방문 때마다 친철하심은 물론이...      0
# 200   성령실장님이 쁘게 잘 잘라주셔서 감사해 요 늘 믿고 맡깁니다 머리를 항상 너무 마...      0
# 201   오늘은 뿌리염색 신데렐라 클리닉 두피 스케일링 하러 왔어요 정기적으로 오는 이곳 ...      0
# 202   항상 갈 때마다 만족입니다 염색이나 펌은 개월에 한 번씩 그리고 영양관리는 한 달...      0
#
# [203 rows x 2 columns]

# %%
df2
# Out:
#                                                   text  label
# 183   최고에 요 역시 시홍쌤 덕분에 인생 샷건졌어요 유머 넘치고 친절하시고 원하는 스타...      0
# 139   오늘은 제 머리하러 왔습니 당 맘 카페서 추천해주셔서 애기들 머리 하러 왔다가 애...      0
# 57    마음에 들게 너무 너무 잘해주셨어요 친절하시고 시술도 꼼꼼하고 너무 좋았습니다 완...      1
# 48    몇 번 실패하고 정말 오랜만에 펌인데 너무 만족스럽습니다 겨울에 잘 어울리는 귀여...      1
# 176   뿌염했는데 색깔 자연스럽게 잘 나와서 넘 좋아요 너무 마음에 드는 갈색입니 당 인...      0
# ..                                                 ...    ...
# 112   늘 친절하시고 머리도 예쁘게 잘해주셔서 감사해 요 촬영보다 드라이를 좀 일찍 받아...      0
# 130   원장님 추천으로 스파클링 스파 받았는데 오일 향도 너무 좋아서 힐링되는 시간 보내...      0
# 81    준오헤어진 디자이너 선생님께 솜브레탈 색 모톤다운 염색 시술 받았어요 탈색한 지도...      1
# 45    두 번째 시아쌤에게 머리했어요 역시나 금손이셔 요 원하는 스타일을 말씀드리면 금방...      1
# 67    어떤 파마를 해야 할지 몰라서 고민이 많았는데 원하는 스타일의 사진들을 보시고 잘...      1
#
# [101 rows x 2 columns]

# %%
df2,df_all5 = train_test_split(dfall5,test_size=0.5,random_state=42,stratify=dfall5['label'].values)

# %%
df_all5
# Out:
#                                                   text  label
# 62    고척동 미용실 개봉역 미용실 고척동 여성컷트 고척동염색 찾으시는 분들에게 추천 드...      1
# 187   역시 말 뭐 말 뭐 경빈 쌤손길 한 번이면 새로 태어나는 기분이에 요 머리가 제 ...      0
# 182   빈곤한 저의 머리숱을 부자로 만들어주셨요 역시 시홍쌤 금손 다른 거뿐만 아니라 드...      0
# 137   평생 한 갈색 머리 중에 가장 마음에 들고 예뻐요 커트도 항상 너무 예쁘고 앞머리...      0
# 174   제가 항상 원하는 머리로 해주시는 유림쌤 새롭게 도전해보는 스타일인데 제 얼굴형에...      0
# ..                                                 ...    ...
# 196   머리가 지저분해서 다듬으러 갔는데 성령쌤이 허쉬 컷 추천해주셨어요 생각도 못했는데...      0
# 181   항상 감사합니다 전 오디너리에서 다시 태어나고 나옵니다 뿌염 말하지 않아도 자신에...      0
# 61    준오헤어 새로 생겼대 서기대 하고 와 봤는데 기대한 것보다 더 더 좋았어요 매장도...      1
# 31    이어링 염색 처음 해봤는데 보는 사람마다 완전 컬러 이쁘다고 해서 진짜 뿌듯해요 ...      1
# 13    머리가 엄청 상해서 속상했는데 수윤 쌤이머리 상한 부분 잘 커트해 주시고 매직펌 ...      1
#
# [102 rows x 2 columns]

# %%
df_all5
# Out:
#                                                   text  label
# 62    고척동 미용실 개봉역 미용실 고척동 여성컷트 고척동염색 찾으시는 분들에게 추천 드...      1
# 187   역시 말 뭐 말 뭐 경빈 쌤손길 한 번이면 새로 태어나는 기분이에 요 머리가 제 ...      0
# 182   빈곤한 저의 머리숱을 부자로 만들어주셨요 역시 시홍쌤 금손 다른 거뿐만 아니라 드...      0
# 137   평생 한 갈색 머리 중에 가장 마음에 들고 예뻐요 커트도 항상 너무 예쁘고 앞머리...      0
# 174   제가 항상 원하는 머리로 해주시는 유림쌤 새롭게 도전해보는 스타일인데 제 얼굴형에...      0
# ..                                                 ...    ...
# 196   머리가 지저분해서 다듬으러 갔는데 성령쌤이 허쉬 컷 추천해주셨어요 생각도 못했는데...      0
# 181   항상 감사합니다 전 오디너리에서 다시 태어나고 나옵니다 뿌염 말하지 않아도 자신에...      0
# 61    준오헤어 새로 생겼대 서기대 하고 와 봤는데 기대한 것보다 더 더 좋았어요 매장도...      1
# 31    이어링 염색 처음 해봤는데 보는 사람마다 완전 컬러 이쁘다고 해서 진짜 뿌듯해요 ...      1
# 13    머리가 엄청 상해서 속상했는데 수윤 쌤이머리 상한 부분 잘 커트해 주시고 매직펌 ...      1
#
# [102 rows x 2 columns]

# %%
# !git clone https://github.com/SOMJANG/Mecab-ko-for-Google-Colab.git
# %cd Mecab-ko-for-Google-Colab
# !bash install_mecab-ko_on_colab190912.sh
# Out:
# Cloning into 'Mecab-ko-for-Google-Colab'...
# remote: Enumerating objects: 115, done.
# remote: Counting objects: 100% (24/24), done.
# remote: Compressing objects: 100% (20/20), done.
# remote: Total 115 (delta 11), reused 10 (delta 3), pack-reused 91
# Receiving objects: 100% (115/115), 1.27 MiB | 9.71 MiB/s, done.
# Resolving deltas: 100% (50/50), done.
# /content/Mecab-ko-for-Google-Colab
# Installing konlpy.....
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.4/19.4 MB 75.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 465.6/465.6 KB 50.3 MB/s eta 0:00:00
# ...
# Done
# Installing mecab-0.996-ko-0.9.2.tar.gz.....
# ...
# from https://bitbucket.org/eunjeon/mecab-ko/downloads/mecab-0.996-ko-0.9.2.tar.gz
# --2023-02-01 12:40:30--  https://bitbucket.org/eunjeon/mecab-ko/downloads/mecab-0.996-ko-0.9.2.tar.gz
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from collections import Counter
from konlpy.tag import Mecab
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
mecab = Mecab()

# %%
#불용어 설정
stopwords = ['도', '는', '다', '의', '가', '이', '은', '한', '에', '하', '고', '을', '를', '인', '듯', '과', '와', '네', '들', '듯', '지', '임', '게', '만', '게임', '겜', '되', '음', '면','있','어','어요','주','로','좋','수','먹','해','기','보','아','시','는데','으로','그램','기','아','었','요','했','에서','스타','것','니','어서','았','같','라','적','미용실','머리','더라고요','는데요','던','셨','헤어','님','잘','나','지만','습니다','죠','다는','받','거','저','제','때','할','분','서','원','까지','내산','겠','라고','셔서','아서','면서','그리고','답니다','아요','때문','보다','더라구요','서','내','해서','다고','트','여기','바로''더','된','이렇게','네요','성신','감','아니','니까','오','좀','세요','길','바로','점','그래서','신','보이','해요','여대','않','두','그','중','또','도록','없이','알','거든요']

# %%
data['tokenized'] =data['text'].astype(str).apply(mecab.morphs)
data['tokenized'] =data['tokenized'].apply(lambda x: [item for item in x if item not in stopwords])

# %%
df_all5['tokenized'] =df_all5['text'].astype(str).apply(mecab.morphs)
df_all5['tokenized'] =df_all5['tokenized'].apply(lambda x: [item for item in x if item not in stopwords])

# %%
# 데이터들의 행과 열 합치기
noad_words = np.hstack(data[data.label == 0]['tokenized'].values)
ad_words = np.hstack(data[data.label == 1]['tokenized'].values)

# %%
noad_word_count = Counter(noad_words)
print(noad_word_count.most_common(20))
# Out:
# [('맛집', 6658), ('맛', 6423), ('안', 4084), ('돈', 3957), ('추천', 3784), ('너무', 3755), ('맛있', 3663), ('팔', 3385), ('더', 3274), ('없', 3161), ('리뷰', 2402), ('됨', 2347), ('일', 2279), ('번', 2263), ('싶', 2248), ('수정', 2190), ('맞', 2177), ('느낌', 2158), ('시간', 2144), ('제품', 2073)]

# %%
ad_word_count = Counter(ad_words)
print(ad_word_count.most_common(20))
# Out:
# [('제품', 6628), ('사용', 4913), ('맛', 4334), ('추천', 4300), ('더', 4019), ('너무', 4009), ('협찬', 3993), ('없', 3844), ('피부', 3236), ('시간', 3104), ('맛집', 3068), ('안', 3032), ('많', 2882), ('맛있', 2833), ('일', 2820), ('정말', 2698), ('됨', 2530), ('제공', 2524), ('수정', 2478), ('번', 2359)]

# %%
plt.rc('font', family='NanumBarunGothic') 
ny=[int(i[1]) for i in noad_word_count.most_common(10)]
nx=[i[0] for i in noad_word_count.most_common(10)]
ay=[int(i[1]) for i in ad_word_count.most_common(10)]
ax=[i[0] for i in ad_word_count.most_common(10)]

# %%
fig,(ax1,ax2) = plt.subplots(1,2,figsize=(10,5))
text_len = data[data['label']==1]['tokenized'].map(lambda x: len(x))
ax1.hist(text_len, color='red')
ax1.set_title('advertisement')
ax1.set_xlabel('length of samples')
ax1.set_ylabel('number of samples')
print('광고성 글의 평균 길이 :', np.mean(text_len))

text_len = data[data['label']==0]['tokenized'].map(lambda x: len(x))
ax2.hist(text_len, color='blue')
ax2.set_title('non-advertisement')
fig.suptitle('Words in texts')
ax2.set_xlabel('length of samples')
ax2.set_ylabel('number of samples')
print('광고가 아닌 글의 평균 길이 :', np.mean(text_len))
plt.show()
# Out:
# 광고성 글의 평균 길이 : 59.05980379826437
# 광고가 아닌 글의 평균 길이 : 47.160906988694755

# %%
from sklearn.model_selection import train_test_split
#X_train,test_x,y_train,test_y=train_test_split(data['tokenized'].values,data['label'].values,test_size=0.3,random_state=3,stratify=data['label'].values)
#X_valid, X_test, y_valid, y_test = train_test_split(test_x,test_y,test_size=0.5,random_state=3,stratify=test_y)

# %%
train_data,test_data = train_test_split(data,test_size=0.2,random_state=42,stratify=data['label'].values)

# %%
X_valid = df_all5['tokenized'].values
y_valid = df_all5['label'].values

X_test = test_data['tokenized'].values
y_test = test_data['label'].values

X_train = train_data['tokenized'].values
y_train = train_data['label'].values

# %%
len(X_valid),len(X_test)
# Out:
# (203, 6294)

# %%
tokenizer = Tokenizer()
tokenizer.fit_on_texts(X_train)

# %%
threshold = 2
total_cnt = len(tokenizer.word_index) # 단어의 수
rare_cnt = 0 # 등장 빈도수가 threshold보다 작은 단어의 개수를 카운트
total_freq = 0 # 훈련 데이터의 전체 단어 빈도수 총 합
rare_freq = 0 # 등장 빈도수가 threshold보다 작은 단어의 등장 빈도수의 총 합

# 단어와 빈도수의 쌍(pair)을 key와 value로 받는다.
for key, value in tokenizer.word_counts.items():
    total_freq = total_freq + value

    # 단어의 등장 빈도수가 threshold보다 작으면
    if(value < threshold):
        rare_cnt = rare_cnt + 1
        rare_freq = rare_freq + value

print('단어 집합(vocabulary)의 크기 :',total_cnt)
print('등장 빈도가 %s번 이하인 희귀 단어의 수: %s'%(threshold - 1, rare_cnt))
print("단어 집합에서 희귀 단어의 비율:", (rare_cnt / total_cnt)*100)
print("전체 등장 빈도에서 희귀 단어 등장 빈도 비율:", (rare_freq / total_freq)*100)
vocab_size = total_cnt - rare_cnt + 2
print('단어 집합의 크기 :',vocab_size)
# Out:
# 단어 집합(vocabulary)의 크기 : 41643
# 등장 빈도가 1번 이하인 희귀 단어의 수: 14457
# 단어 집합에서 희귀 단어의 비율: 34.71651898278222
# 전체 등장 빈도에서 희귀 단어 등장 빈도 비율: 1.083054397693799
# 단어 집합의 크기 : 27188

# %%
tokenizer = Tokenizer(vocab_size, oov_token = 'OOV') 
tokenizer.fit_on_texts(X_train)
X_train = tokenizer.texts_to_sequences(X_train)
X_test = tokenizer.texts_to_sequences(X_test)
X_valid = tokenizer.texts_to_sequences(X_valid)

# %%
print('리뷰의 최대 길이 :',max(len(l) for l in X_train))
print('리뷰의 평균 길이 :',sum(map(len, X_train))/len(X_train))
plt.hist([len(s) for s in X_train], bins=50)
plt.xlabel('length of samples')
plt.ylabel('number of samples')
plt.show()
# Out:
# 리뷰의 최대 길이 : 579
# 리뷰의 평균 길이 : 53.02017794725135

# %%
def below_threshold_len(max_len, nested_list):
  cnt = 0
  for s in nested_list:
    if(len(s) <= max_len):
        cnt = cnt + 1
  print('전체 샘플 중 길이가 %s 이하인 샘플의 비율: %s'%(max_len, (cnt / len(nested_list))*100))

# %%
max_len = 400
below_threshold_len(max_len, X_train)
# Out:
# 전체 샘플 중 길이가 400 이하인 샘플의 비율: 99.91658722592945

# %%
X_train = pad_sequences(X_train, maxlen = max_len)
X_test = pad_sequences(X_test, maxlen = max_len)
X_valid = pad_sequences(X_valid , maxlen = max_len)

# %%
import re
from tensorflow.keras.layers import Embedding, Dense, LSTM, Bidirectional
from tensorflow.keras.models import Sequential
from tensorflow.keras.models import load_model
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

# %%
model = Sequential()
model.add(Embedding(vocab_size, 100))
model.add(Bidirectional(LSTM(100)))
model.add(Dense(1, activation='sigmoid'))
mc = ModelCheckpoint('/content/drive/MyDrive/비타민 프로젝트/bilstm_model_0201_5.h5', monitor='val_acc', mode='max', verbose=1, save_best_only=True)
model.compile(optimizer='rmsprop', loss='binary_crossentropy', metrics=['acc'])
history = model.fit(X_train, y_train, epochs=15, callbacks=[mc], batch_size=256, validation_data=(X_valid, y_valid))
# Out:
# Epoch 1/15
# 98/99 [============================>.] - ETA: 0s - loss: 0.5082 - acc: 0.7618
# Epoch 1: val_acc improved from -inf to 0.59804, saving model to /content/drive/MyDrive/비타민 프로젝트/bilstm_model_0201_5.h5
# 99/99 [==============================] - 12s 83ms/step - loss: 0.5080 - acc: 0.7619 - val_loss: 1.0234 - val_acc: 0.5980
# Epoch 2/15
# 98/99 [============================>.] - ETA: 0s - loss: 0.3495 - acc: 0.8635
# Epoch 2: val_acc improved from 0.59804 to 0.71569, saving model to /content/drive/MyDrive/비타민 프로젝트/bilstm_model_0201_5.h5
# 99/99 [==============================] - 8s 77ms/step - loss: 0.3491 - acc: 0.8637 - val_loss: 0.7922 - val_acc: 0.7157
# Epoch 3/15
# 98/99 [============================>.] - ETA: 0s - loss: 0.2613 - acc: 0.8971
# Epoch 3: val_acc did not improve from 0.71569
# 99/99 [==============================] - 7s 74ms/step - loss: 0.2613 - acc: 0.8970 - val_loss: 0.7835 - val_acc: 0.6961
# Epoch 4/15
# ...

# %%
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
loaded_model = load_model('/content/drive/MyDrive/비타민 프로젝트/bilstm_model_0201_5.h5')
print("테스트 정확도: %.4f" % (loaded_model.evaluate(X_test, y_test)[1]))
# Out:
# 197/197 [==============================] - 3s 14ms/step - loss: 0.3706 - acc: 0.8543
# 테스트 정확도: 0.8543

# %%
#테스트 데이터 

#df2=pd.read_csv('/content/drive/MyDrive/비타민 프로젝트/네이버지도테스트최종데이터2.csv')

# %%
df2['label'].value_counts()
# Out:
# 0    51
# 1    50
# Name: label, dtype: int64

# %%
df2.reset_index(drop=True,inplace=True)

# %%
# 띄어쓰기 
from pykospacing import Spacing
spacing = Spacing()
import kss

def sentiment_predict(new_sentence):
  new_sentence=new_sentence.replace(" ", "")
  new_sentence=spacing(new_sentence)
  new_sentence=kss.split_sentences(new_sentence)
  new_sentence=str(new_sentence)
  new_sentence= re.sub(r'[^가-힣 ]','', new_sentence)
  new_sentence = mecab.morphs(new_sentence) # 토큰화
  new_sentence = [word for word in new_sentence if not word in stopwords] # 불용어 제거
  encoded = tokenizer.texts_to_sequences([new_sentence]) # 정수 인코딩
  pad_new = pad_sequences(encoded, maxlen = max_len) # 패딩
  score = float(loaded_model.predict(pad_new)) # 예측
  if(score > 0.2):
    df2['evaluation'][i]="{:.2f}% 확률로 광고입니다.".format(score * 100)
  else:
    df2['evaluation'][i]="{:.2f}% 확률로 비광고입니다.".format((1 - score) * 100)

# %%
df2
# Out:
#      index                                               text  label  \
# 0      183   최고에 요 역시 시홍쌤 덕분에 인생 샷건졌어요 유머 넘치고 친절하시고 원하는 스타...      0
# 1      139   오늘은 제 머리하러 왔습니 당 맘 카페서 추천해주셔서 애기들 머리 하러 왔다가 애...      0
# 2       57   마음에 들게 너무 너무 잘해주셨어요 친절하시고 시술도 꼼꼼하고 너무 좋았습니다 완...      1
# 3       48   몇 번 실패하고 정말 오랜만에 펌인데 너무 만족스럽습니다 겨울에 잘 어울리는 귀여...      1
# 4      176   뿌염했는데 색깔 자연스럽게 잘 나와서 넘 좋아요 너무 마음에 드는 갈색입니 당 인...      0
# ..     ...                                                ...    ...
# 96     112   늘 친절하시고 머리도 예쁘게 잘해주셔서 감사해 요 촬영보다 드라이를 좀 일찍 받아...      0
# 97     130   원장님 추천으로 스파클링 스파 받았는데 오일 향도 너무 좋아서 힐링되는 시간 보내...      0
# 98      81   준오헤어진 디자이너 선생님께 솜브레탈 색 모톤다운 염색 시술 받았어요 탈색한 지도...      1
# 99      45   두 번째 시아쌤에게 머리했어요 역시나 금손이셔 요 원하는 스타일을 말씀드리면 금방...      1
# 100     67   어떤 파마를 해야 할지 몰라서 고민이 많았는데 원하는 스타일의 사진들을 보시고 잘...      1
#
#              evaluation
# 0                     0
# 1    97.88% 확률로 비광고입니다.
# 2     76.21% 확률로 광고입니다.
# 3     47.60% 확률로 광고입니다.
# ...

# %%
df2['evaluation']=0

# %%
for i in range (0,101):
  sentiment_predict(df2['text'][i])
# Out:
# ...
# 1/1 [==============================] - 0s 25ms/step

# %%
#21
df2['광고']=df2['evaluation'].str[11:13]

# %%
df2
# Out:
#      index                                               text  label  \
# 0      183   최고에 요 역시 시홍쌤 덕분에 인생 샷건졌어요 유머 넘치고 친절하시고 원하는 스타...      0
# 1      139   오늘은 제 머리하러 왔습니 당 맘 카페서 추천해주셔서 애기들 머리 하러 왔다가 애...      0
# 2       57   마음에 들게 너무 너무 잘해주셨어요 친절하시고 시술도 꼼꼼하고 너무 좋았습니다 완...      1
# 3       48   몇 번 실패하고 정말 오랜만에 펌인데 너무 만족스럽습니다 겨울에 잘 어울리는 귀여...      1
# 4      176   뿌염했는데 색깔 자연스럽게 잘 나와서 넘 좋아요 너무 마음에 드는 갈색입니 당 인...      0
# ..     ...                                                ...    ...
# 96     112   늘 친절하시고 머리도 예쁘게 잘해주셔서 감사해 요 촬영보다 드라이를 좀 일찍 받아...      0
# 97     130   원장님 추천으로 스파클링 스파 받았는데 오일 향도 너무 좋아서 힐링되는 시간 보내...      0
# 98      81   준오헤어진 디자이너 선생님께 솜브레탈 색 모톤다운 염색 시술 받았어요 탈색한 지도...      1
# 99      45   두 번째 시아쌤에게 머리했어요 역시나 금손이셔 요 원하는 스타일을 말씀드리면 금방...      1
# 100     67   어떤 파마를 해야 할지 몰라서 고민이 많았는데 원하는 스타일의 사진들을 보시고 잘...      1
#
#              evaluation  광고
# 0     33.15% 확률로 광고입니다.  광고
# 1    97.88% 확률로 비광고입니다.  비광
# 2     76.21% 확률로 광고입니다.  광고
# ...

# %%
df2_광고=df2[df2['label']==1]
df2_비광고=df2[df2['label']==0]

# %%
df2_광고['광고'].value_counts()
# Out:
# 광고    35
# 비광    15
# Name: 광고, dtype: int64

# %%
df2_비광고['광고'].value_counts()
# Out:
# 비광    35
# 광고    16
# Name: 광고, dtype: int64
