# %%
import pandas as pd
import numpy as np
import torch
import re
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize 
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
import warnings
warnings.filterwarnings('ignore')

# %%
df1=pd.read_csv('/content/drive/MyDrive/비타민 프로젝트/블로그_비광고_전처리.csv')
df2=pd.read_csv('/content/drive/MyDrive/비타민 프로젝트/블로그_광고_전처리.csv')
df3=pd.read_csv('/content/drive/MyDrive/비타민 프로젝트/인스타_비광고_전처리_추가.csv')
df4=pd.read_csv('/content/drive/MyDrive/비타민 프로젝트/인스타_광고_전처리_추가.csv')

# %%
df2.drop('Unnamed: 0', axis=1,inplace=True)
df2
# Out:
#                                                    text  label
# 0     "제주 여행의 일정 중 한 곳이던\n서귀포 올레시장 먹거리로 아침겸 점심을 누리고 ...      1
# 1     "허기를 채우려고 감자 샐러드를\n먹어보니 보드랍고 꼬숩한 맛이 너무 좋았어요.\n...      1
# 2     "연이어 앞에 고등어구이는 이 날 간만에 즐겨봤어요.\n그냥 봤을 때는 평범한 비주...      1
# 3     "친구도 밥에 얹어서 가득 맛보더니\n맛있다며 감탄하더라고요.\n살코기만 먹어도 너...      1
# 4     "밑반찬에 나오는 미역국도 미역도\n알차고 삼삼하며 개운하니 떠먹기 좋았어요.\n저...      1
# ...                                                 ...    ...
# 5403  거기 그치지 않고 좀 더 많은 효능을 찾고 계시는 분들은\n같은 곳에서 만드는\n칼...      1
# 5404  저는 이날 혼자 가서 천천히 시간을 보내봤는데\n가족이랑 아이랑 친구랑 연인이랑 홍...      1
# 5405  손등에 먼저 사용해 줬는데요\n부드럽게 발리면서 피부에 착 달라붙어\n전체적으로 윤...      1
# 5406  그래서 지루성두피염샴푸로\n이것을 선택해서 사용하고 있죠.\n저와 가족들 모두 사용...      1
# 5407  처음엔 순해서 세정력이\n떨어질까봐 걱정했거든요.\n밖에 외출하고 오면\n미세먼지들...      1
#
# [5408 rows x 2 columns]

# %%
df3.rename(columns={'content':'text'}, inplace=True)
df4.rename(columns={'content':'text'}, inplace=True)

# %%
data=pd.concat([df1,df2,df3,df4],ignore_index=True)
data
# Out:
#                                                     text  label
# 0      ㅂ사 전동젖병세척솔\n사실상 이걸쓰려고........ 쓰는 포스트이기도 한........      0
# 1      2. ㅇ사 수유시트\n분유수유할 때 쓰는걸로 유명한 수유시트죠, 모양이 고정된 만원...      0
# 2      3. ㅁ사 아기비데\n아기비데는 사실 ㅊㅋ나 ㅍㅍㅂㅂ가 젤 유명하죠~ 저는 당시에 ...      0
# 3      4. ㅎ사 홈캠(이건 추천이기도 하고 불편한 점)\n홈캠! 자체는 정말 추천! 조리...      0
# 4      바구니배 금액\n성인 4불 / 아동2불\n(4불 : 90,000VND)\n만 11세...      0
# ...                                                  ...    ...
# 20942   제품협찬 @terrazen_korea 🐤피부보습부터 장벽 강화까지 한번에!아쿠아 ...      1
# 20943   제품협찬🌺편안하면서 고급스러운 라브데뜨 브이넥 5부 소매 트임 랩 리본 롱 원피스...      1
# 20944   제품협찬🐬심플하면서도 이지한 린넨 슬랙스에요!🐳편안하고 시원한 린넨 소재로 멋스럽...      1
# 20945   협찬🏝️LEPSBOMB은 자연유래성분만을 고집하는 입욕 코스메틱 브랜드입니다당신이...      1
# 20946   제품협찬🏝️세계최초 산양유가 아닌 양유 츄어블!엔젤 블루베리 양유 츄어블 이에요⛰...      1
#
# [20947 rows x 2 columns]

# %%
data.to_csv('/content/drive/MyDrive/비타민 프로젝트/원본데이터.csv', index = False)

# %%
data['label'].value_counts()
# Out:
# 1    10588
# 0    10359
# Name: label, dtype: int64

# %%
# !proper installation of python3
# !proper installation of pip

# !pip install tensorflow
# !pip install keras

# !pip install git+https://github.com/haven-jeon/PyKoSpacing.git
# Out:
# /bin/bash: proper: command not found
# /bin/bash: proper: command not found
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Cloning https://github.com/haven-jeon/PyKoSpacing.git to /tmp/pip-req-build-rpften1b
#   Running command git clone --filter=blob:none --quiet https://github.com/haven-jeon/PyKoSpacing.git /tmp/pip-req-build-rpften1b
#   Resolved https://github.com/haven-jeon/PyKoSpacing.git to commit fc2eb9f7837c9f4d256560a47437f4c11decb934
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 511.8/511.8 MB 2.6 MB/s eta 0:00:00
# ...
#   Created wheel for pykospacing: filename=pykospacing-0.5-py3-none-any.whl size=2268650 sha256=da5d278f63631022a82c26a70fc42ad4d67c993160791fc5df06ffed0b211c64
# ...

# %%
#데이터 공백 제거
for i in range (0,20947):
  data['text'][i] = data['text'][i].replace(" ", "")

# %%
data
# Out:
#                                                     text  label
# 0      ㅂ사전동젖병세척솔\n사실상이걸쓰려고........쓰는포스트이기도한.....\n출산전...      0
# 1      2.ㅇ사수유시트\n분유수유할때쓰는걸로유명한수유시트죠,모양이고정된만원대에서구매할수있고...      0
# 2      3.ㅁ사아기비데\n아기비데는사실ㅊㅋ나ㅍㅍㅂㅂ가젤유명하죠~저는당시에라이브방송에서핫딜떠...      0
# 3      4.ㅎ사홈캠(이건추천이기도하고불편한점)\n홈캠!자체는정말추천!조리원퇴소하고나서산후도...      0
# 4      바구니배금액\n성인4불/아동2불\n(4불:90,000VND)\n만11세까지아동,만6...      0
# ...                                                  ...    ...
# 20942  제품협찬@terrazen_korea🐤피부보습부터장벽강화까지한번에!아쿠아리차지트리트먼...      1
# 20943  제품협찬🌺편안하면서고급스러운라브데뜨브이넥5부소매트임랩리본롱원피스에요🌺🌷가슴부분이랩이...      1
# 20944  제품협찬🐬심플하면서도이지한린넨슬랙스에요!🐳편안하고시원한린넨소재로멋스럽게연출할수있는아...      1
# 20945  협찬🏝️LEPSBOMB은자연유래성분만을고집하는입욕코스메틱브랜드입니다당신이가장사랑하는...      1
# 20946  제품협찬🏝️세계최초산양유가아닌양유츄어블!엔젤블루베리양유츄어블이에요⛰🗺️양유츄어블은무...      1
#
# [20947 rows x 2 columns]

# %%
# 띄어쓰기 
from pykospacing import Spacing
spacing = Spacing(rules=['내돈내산'])

for i in range (0,20947):
  data['text'][i] = spacing(data['text'][i])

# %%
data['text']=data['text'].astype(str)

# %%
# 여기까지 전처리한거 csv로 저장
data.to_csv('/content/drive/MyDrive/비타민 프로젝트/data3.csv', index = False)

# %%
data=pd.read_csv('/content/drive/MyDrive/비타민 프로젝트/data3.csv')

# %%
data
# Out:
#                                                     text  label
# 0      ㅂ 사전동 젖병 세척솔 사실상 이걸 쓰려고........ 쓰는 포스트이기도 한......      0
# 1      2.ㅇ사수유 시트 분유수유할 때 쓰는 걸로 유명한 수유 시트죠, 모양이 고정된 만원...      0
# 2      3.ㅁ사 아기비데 아기 비 데는 사실 ㅊㅋ나 ㅍㅍㅂㅂ가젤 유명하죠~저는 당시에라이브...      0
# 3      4.ㅎ사 홈캠(이건 추천이기도 하고 불편한 점) 홈캠! 자체는 정말 추천! 조리원 ...      0
# 4      바구니 배 금액 성인 4불 / 아동2 불 (4불: 90,000VND) 만 11세까지...      0
# ...                                                  ...    ...
# 20942  제품 협찬@ter razen_korea 🐤 피부 보습부터 장벽 강화까지 한 번에 !...      1
# 20943  제품 협찬 🌺편안하면서 고급스러운 라브데뜨브이넥 5부소매트임랩 리본롱 원피스에 요 ...      1
# 20944  제품 협찬🐬 심플하면서도 이지한 린넨 슬랙스에요!🐳편안하고 시원한 린넨 소재로 멋스...      1
# 20945  협찬🏝️ LEPSBOMB은 자연유래 성분만을 고집하는 입욕 코스메틱 브랜드입니다당신...      1
# 20946  제품 협찬 🏝️ 세계 최초 산양유가 아닌 양유츄어블!엔젤블루베리 양유츄어블이에 요 ...      1
#
# [20947 rows x 2 columns]

# %%
# !pip install kss
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.7/77.7 KB 5.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 131.3/131.3 KB 12.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 26.4/26.4 MB 28.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for kss: filename=kss-4.5.1-py3-none-any.whl size=53218 sha256=1b73641f7d7a8ae5a564afd55e5f8f9796e2609e3f6ed030c63bfa51064da4c5
#   Stored in directory: /root/.cache/pip/wheels/8c/f9/05/a93eb0defc9eed494ee4d42e3d9076fade98f08982f41cf09f
# ...
#   Created wheel for pecab: filename=pecab-1.0.8-py3-none-any.whl size=26646667 sha256=261a75f7740f3f3cf86db3afd843228d734ef489f9ad50bfd591a042d4cc09bc
#   Stored in directory: /root/.cache/pip/wheels/a9/98/a3/085a909aa25805f321467a3af3b80d43b6094ed335b4818775
# Successfully built kss pecab
# ...

# %%
data['text']=data['text'].astype(str)

# %%
data
# Out:
#                                                     text  label
# 0      ㅂ 사전동 젖병 세척솔 사실상 이걸 쓰려고........ 쓰는 포스트이기도 한......      0
# 1      2.ㅇ사수유 시트 분유수유할 때 쓰는 걸로 유명한 수유 시트죠, 모양이 고정된 만원...      0
# 2      3.ㅁ사 아기비데 아기 비 데는 사실 ㅊㅋ나 ㅍㅍㅂㅂ가젤 유명하죠~저는 당시에라이브...      0
# 3      4.ㅎ사 홈캠(이건 추천이기도 하고 불편한 점) 홈캠! 자체는 정말 추천! 조리원 ...      0
# 4      바구니 배 금액 성인 4불 / 아동2 불 (4불: 90,000VND) 만 11세까지...      0
# ...                                                  ...    ...
# 20942  제품 협찬@ter razen_korea 🐤 피부 보습부터 장벽 강화까지 한 번에 !...      1
# 20943  제품 협찬 🌺편안하면서 고급스러운 라브데뜨브이넥 5부소매트임랩 리본롱 원피스에 요 ...      1
# 20944  제품 협찬🐬 심플하면서도 이지한 린넨 슬랙스에요!🐳편안하고 시원한 린넨 소재로 멋스...      1
# 20945  협찬🏝️ LEPSBOMB은 자연유래 성분만을 고집하는 입욕 코스메틱 브랜드입니다당신...      1
# 20946  제품 협찬 🏝️ 세계 최초 산양유가 아닌 양유츄어블!엔젤블루베리 양유츄어블이에 요 ...      1
#
# [20947 rows x 2 columns]

# %%
#한국어 문장분리 파이썬 라이브러리 kss
import kss
for i in range (0,20947):
  data['text'][i] = kss.split_sentences(data['text'][i])
# Out:
# WARNING:root:Oh! You have mecab in your environment. Kss will take this as a backend! :D

# %%
data['text']=data['text'].astype(str)

# %%
#한글 아닌건 다 제거 
p= re.compile('[^가-힣]+')
for i in range (0,20947):
  data['text'][i]=p.sub(" ",data['text'][i])

# %%
data.to_csv('/content/drive/MyDrive/비타민 프로젝트/data10.csv', index = False)
#맞춤법 검사 안한거
